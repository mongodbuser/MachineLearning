# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# # --------------------------------------------------------------------------------------------
#
# # ******************* Syntactic Processing Assignment ********************************
#
# ### **********************    Part 1 - HMMs and Viterbi algorithm for POS tagging **********************************************
#
# ### Author: Sushma KR ############
# ### Date: 27th July 2018
#
# # --------------------------------------------------------------------------------------------

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import random

import numpy as np
import pandas as pd

import time

import re

import nltk
from nltk import word_tokenize 
nltk.download('universal_tagset')

import sklearn
from sklearn.model_selection import train_test_split
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/raagzcd/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
len(nltk_data)
# Out:
# 3914

# %%
# first few tagged sentences
print(nltk_data[:30])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')], [('Lorillard', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('the', 'DET'), ('unit', 'NOUN'), ('of', 'ADP'), ('New', 'ADJ'), ('York-based', 'ADJ'), ('Loews', 'NOUN'), ('Corp.', 'NOUN'), ('that', 'DET'), ('*T*-2', 'X'), ('makes', 'VERB'), ('Kent', 'NOUN'), ('cigarettes', 'NOUN'), (',', '.'), ('stopped', 'VERB'), ('using', 'VERB'), ('crocidolite', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('Micronite', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('in', 'ADP'), ('1956', 'NUM'), ('.', '.')], [('Although', 'ADP'), ('preliminary', 'ADJ'), ('findings', 'NOUN'), ('were', 'VERB'), ('reported', 'VERB'), ('*-2', 'X'), ('more', 'ADV'), ('than', 'ADP'), ('a', 'DET'), ('year', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('the', 'DET'), ('latest', 'ADJ'), ('results', 'NOUN'), ('appear', 'VERB'), ('in', 'ADP'), ('today', 'NOUN'), ("'s", 'PRT'), ('New', 'NOUN'), ('England', 'NOUN'), ('Journal', 'NOUN'), ('of', 'ADP'), ('Medicine', 'NOUN'), (',', '.'), ('a', 'DET'), ('forum', 'NOUN'), ('likely', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('bring', 'VERB'), ('new', 'ADJ'), ('attention', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('problem', 'NOUN'), ('.', '.')], [('A', 'DET'), ('Lorillard', 'NOUN'), ('spokewoman', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('This', 'DET'), ('is', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('story', 'NOUN'), ('.', '.')], [('We', 'PRON'), ("'re", 'VERB'), ('talking', 'VERB'), ('about', 'ADP'), ('years', 'NOUN'), ('ago', 'ADP'), ('before', 'ADP'), ('anyone', 'NOUN'), ('heard', 'VERB'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('having', 'VERB'), ('any', 'DET'), ('questionable', 'ADJ'), ('properties', 'NOUN'), ('.', ...

# %%
# Splitting into training and test data
random.seed(1234)
train_set, test_set = train_test_split(nltk_data, train_size = 0.95, random_state = 42)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
# Get list of all words along with the POS tags assigned to each word
train_tagged_words = [tup for sent in train_set for tup in sent]

# %%
# Print number of word, POS tag combinations obtained
print(len(train_tagged_words))
# Out:
# 95589

# %%
# list of all words
[tup[0] for tup in train_tagged_words]
# Out:
# ['Bank',
#  'of',
#  'New',
#  'England',
#  "'s",
#  'shares',
#  'are',
#  'traded',
#  '*-1',
#  'on',
#  'the',
#  'New',
#  'York',
#  'Stock',
#  'Exchange',
#  '.',
#  '$',
#  '130',
#  'million',
#  '*U*',
#  'of',
#  'general',
#  'obligation',
#  'distributable',
#  'state',
#  'aid',
#  'bonds',
#  'due',
#  '1991-2000',
#  'and',
#  '2009',
#  ',',
#  'tentatively',
#  'priced',
#  '*',
#  'by',
#  'a',
#  'Chemical',
#  'Securities',
#  'Inc.',
#  'group',
#  '*',
#  'to',
#  'yield',
#  'from',
#  '6.20',
#  '%',
#  'in',
#  '1991',
#  'to',
#  '7.272',
#  '%',
#  'in',
#  '2009',
#  '.',
#  '``',
#  'They',
#  'were',
#  'a',
#  'self-perpetuating',
#  'club',
#  'that',
#  '*T*-229',
#  'treated',
#  'the',
#  'tower',
#  'as',
#  'sort',
#  'of',
#  'a',
#  'separate',
#  'premises',
#  ',',
#  "''",
#  'the',
#  'Vicar',
#  'Hummerstone',
#  'says',
#  '*T*-1',
#  '.',
#  'Valley',
#  'Federal',
#  'Savings',
#  '&',
#  'Loan',
#  'Association',
#  'took',
#  'an',
#  '$',
#  '89.9',
#  'million',
#  '*U*',
#  'charge',
#  'as',
#  'it',
#  'reported',
#  'a',
#  'third-quarter',
#  'loss',
#  'of',
#  '$',
#  '70.7',
#  'million',
#  '*U*',
#  ',',
#  'or',
#  '$',
#  '12.09',
#  '*U*',
#  'a',
#  'share',
#  '.',
#  '``',
#  'The',
#  'Herald',
#  'was',
#  'a',
#  'survivor',
#  'from',
#  'a',
#  'bygone',
#  'age',
#  ',',
#  "''",
#  'said',
#  '*T*-1',
#  'J.',
#  'Kendrick',
#  'Noble',
#  ',',
#  'a',
#  'media',
#  'analyst',
#  'with',
#  'PaineWebber',
#  'Inc',
#  '.',
#  'The',
#  'Midwest',
#  'Financial',
#  'subsidiary',
#  'banks',
#  'will',
#  'continue',
#  '*-1',
#  'to',
#  'operate',
#  'under',
#  'their',
#  'current',
#  'names',
#  'until',
#  'early',
#  '1990',
#  ',',
#  'when',
#  'each',
#  'will',
#  'adopt',
#  'the',
#  'First',
#  'of',
#  'America',
#  'name',
#  '*T*-2',
#  '.',
#  'But',
#  'many',
#  'banks',
#  'are',
#  'turning',
#  'away',
#  'from',
#  'strict',
#  'price',
#  'competition',
#  '.',
#  'And',
#  'I',
#  'apparently',
#  'had',
#  'no',
#  'right',
#  '*',
#  'to',
#  'print',
#  'hither',
#  'what',
#  'the',
#  'Voice',
#  'was',
#  'booming',
#  '*T*-2',
#  'to',
#  'yon',
#  '.',
#  'However',
#  ',',
#  'none',
#  'of',
#  'the',
#  'big',
#  'three',
#  'weeklies',
#  'recorded',
#  'circulation',
#  'gains',
#  'recently',
#  '.',
#  'Both',
#  'indicators',
#  'were',
#  'viewed',
#  '*-1',
#  'as',
#  'signs',
#  'that',
#  'the',
#  'nation',
#  "'s",
#  'industrial',
#  'sector',
#  'is',
#  'growing',
#  'very',
#  'slowly',
#  ',',
#  'if',
#  'at',
#  'all',
#  '.',
#  'A',
#  'second',
#  'ship',
#  'is',
#  'now',
#  'expected',
#  '*-2',
#  'to',
#  'be',
#  'delivered',
#  '*-1',
#  'late',
#  'next',
#  'year',
#  'or',
#  'early',
#  'in',
#  '1991',
#  '.',
#  'In',
#  'October',
#  '1988',
#  ',',
#  '21.1',
#  '%',
#  'said',
#  '0',
#  'business',
#  'conditions',
#  'would',
#  'improve',
#  '.',
#  'The',
#  'announcement',
#  'follows',
#  'a',
#  'sharper',
#  '$',
#  '2.2',
#  'billion',
#  '*U*',
#  'decline',
#  'in',
#  'the',
#  'country',
#  "'s",
#  'foreign',
#  'reserves',
#  'in',
#  'September',
#  'to',
#  '$',
#  '86.12',
#  'billion',
#  '*U*',
#  '.',
#  'Michael',
#  'Henderson',
#  ',',
#  '51-year-old',
#  'group',
#  'chief',
#  'executive',
#  'of',
#  'this',
#  'U.K.',
#  'metals',
#  'and',
#  'industrial',
#  'materials',
#  'maker',
#  ',',
#  'will',
#  'become',
#  'chairman',
#  'in',
#  'May',
#  ',',
#  '*-1',
#  'succeeding',
#  'Ian',
#  'Butler',
#  ',',
#  '64',
#  ',',
#  'who',
#  '*T*-161',
#  'is',
#  'retiring',
#  '.',
#  'Partly',
#  'because',
#  'of',
#  'worries',
#  'about',
#  'potential',
#  'abuse',
#  ',',
#  'however',
#  ',',
#  'he',
#  'says',
#  '0',
#  'the',
#  'state',
#  'will',
#  'begin',
#  '*-1',
#  'keeping',
#  'closer',
#  'track',
#  'of',
#  'achievement-test',
#  'preparation',
#  'booklets',
#  'next',
#  'spring',
#  '.',
#  'He',
#  'succeeds',
#  'Terrence',
#  'D.',
#  'Daniels',
#  ',',
#  'formerly',
#  'a',
#  'W.R.',
#  'Grace',
#  'vice',
#  'chairman',
#  ',',
#  'who',
#  '*T*-11',
#  'resigned',
#  '.',
#  'Scientists',
#  'had',
#  'obtained',
#  'even',
#  'higher',
#  'current-carrying',
#  'capacity',
#  'in',
#  'thin',
#  'films',
#  'of',
#  'the',
#  'new',
#  'superconductors',
#  ',',
#  'but',
#  'have',
#  'had',
#  'problems',
#  '*-2',
#  'increasing',
#  'the',
#  'amount',
#  'of',
#  'current',
#  'that',
#  'bulk',
#  'crystals',
#  'could',
#  'carry',
#  '*T*-1',
#  '.',
#  'USX',
#  'was',
#  'cited',
#  '*-1',
#  'by',
#  'OSHA',
#  'for',
#  'several',
#  'health',
#  'and',
#  'safety',
#  'violations',
#  'at',
#  'two',
#  'Pennsylvania',
#  'plants',
#  'and',
#  'may',
#  'face',
#  'a',
#  'record',
#  'fine',
#  'of',
#  '$',
#  '7.3',
#  'million',
#  '*U*',
#  '.',
#  'Stock-index',
#  'futures',
#  '--',
#  'Contracts',
#  '*',
#  'to',
#  'buy',
#  'or',
#  'sell',
#  'the',
#  'cash',
#  'value',
#  'of',
#  'a',
#  'stock',
#  'index',
#  'by',
#  'a',
#  'certain',
#  'date',
#  '.',
#  'The',
#  'idea',
#  ',',
#  'of',
#  'course',
#  ':',
#  '*',
#  'to',
#  'prove',
#  'to',
#  '125',
#  'corporate',
#  'decision',
#  'makers',
#  'that',
#  'the',
#  'buckle',
#  'on',
#  'the',
#  'Rust',
#  'Belt',
#  'is',
#  "n't",
#  'so',
#  'rusty',
#  'after',
#  'all',
#  ',',
#  'that',
#  'it',
#  "'s",
#  'a',
#  'good',
#  'place',
#  '0',
#  'for',
#  'a',
#  'company',
#  'to',
#  'expand',
#  '*T*-1',
#  '.',
#  'Backe',
#  'Group',
#  'Inc.',
#  'agreed',
#  '*-1',
#  'to',
#  'acquire',
#  'Atlantic',
#  'Publications',
#  'Inc.',
#  ',',
#  'which',
#  '*T*-141',
#  'has',
#  '30',
#  'community',
#  'papers',
#  'and',
#  'annual',
#  'sales',
#  'of',
#  '$',
#  '7',
#  'million',
#  '*U*',
#  '.',
#  'The',
#  'one',
#  'character',
#  'at',
#  'least',
#  'somewhat',
#  'interesting',
#  'was',
#  'Irving',
#  'Louis',
#  'Lobsenz',
#  ',',
#  'a',
#  'pediatrician',
#  'who',
#  '*T*-1',
#  'changed',
#  'his',
#  'name',
#  'to',
#  'Rusty',
#  'Kent',
#  'London',
#  'and',
#  'became',
#  'a',
#  'master',
#  'gambler',
#  'and',
#  'author',
#  'of',
#  'a',
#  'book',
#  'on',
#  'blackjack',
#  '.',
#  'The',
#  'worst',
#  'crop',
#  'damage',
#  'occurred',
#  'in',
#  'the',
#  'Midwestern',
#  'Corn',
#  'Belt',
#  'and',
#  'the',
#  'northern',
#  'Great',
#  'Plains',
#  '.',
#  'Mr.',
#  'Taccetta',
#  'says',
#  '0',
#  'he',
#  'had',
#  'just',
#  'recouped',
#  'the',
#  '$',
#  '5,000',
#  '*U*',
#  '0',
#  'he',
#  'lost',
#  '*T*-1',
#  'in',
#  'the',
#  '1987',
#  'crash',
#  'when',
#  'he',
#  'lost',
#  'more',
#  'money',
#  'last',
#  'Oct.',
#  '13',
#  '*T*-2',
#  '.',
#  'Most',
#  'of',
#  'the',
#  'picture',
#  'is',
#  'taken',
#  'up',
#  'with',
#  'endless',
#  'scenes',
#  'of',
#  'many',
#  'people',
#  'either',
#  'fighting',
#  'or',
#  'eating',
#  'and',
#  'drinking',
#  '*-1',
#  'to',
#  'celebrate',
#  'victory',
#  '.',
#  'Institutions',
#  'mostly',
#  'remained',
#  'on',
#  'the',
#  'sidelines',
#  'because',
#  'of',
#  'uncertainty',
#  'regarding',
#  'interest',
#  'rates',
#  'and',
#  'the',
#  'dollar',
#  '.',
#  'In',
#  'San',
#  'Francisco',
#  ',',
#  'its',
#  'backers',
#  'concede',
#  '0',
#  'the',
#  'ballpark',
#  'is',
#  'at',
#  'best',
#  'running',
#  'even',
#  'in',
#  'the',
#  'polls',
#  '.',
#  '*-1',
#  'The',
#  'son',
#  'of',
#  'a',
#  'physicist',
#  ',',
#  'Mr.',
#  'Hahn',
#  'skipped',
#  'first',
#  'grade',
#  'because',
#  'his',
#  'reading',
#  'ability',
#  'was',
#  'so',
#  'far',
#  'above',
#  'his',
#  'classmates',
#  '.',
#  'Some',
#  'of',
#  'his',
#  'observations',
#  'about',
#  'Japanese',
#  'management',
#  'style',
#  'are',
#  'on',
#  'the',
#  'mark',
#  '.',
#  'The',
#  'Bougainville',
#  'copper',
#  'mine',
#  'has',
#  'been',
#  'inoperative',
#  'since',
#  'May',
#  '15',
#  'because',
#  'of',
#  'attacks',
#  'by',
#  'native',
#  'landowners',
#  'who',
#  '*T*-1',
#  'want',
#  'Bougainville',
#  'to',
#  'secede',
#  'from',
#  'Papua-New',
#  'Guinea',
#  '.',
#  'Nonetheless',
#  ',',
#  'plenty',
#  'of',
#  'U.S.',
#  'analysts',
#  'and',
#  'money',
#  'managers',
#  'are',
#  'aghast',
#  'at',
#  'the',
#  'lofty',
#  'trading',
#  'levels',
#  'of',
#  'some',
#  'country',
#  'funds',
#  '.',
#  'The',
#  'new',
#  'Wall',
#  'Street',
#  'of',
#  'computers',
#  'and',
#  'automated',
#  'trading',
#  'threatens',
#  '*-1',
#  'to',
#  'make',
#  'dinosaurs',
#  'of',
#  'the',
#  '49',
#  'Big',
#  'Board',
#  'stock-specialist',
#  'firms',
#  '.',
#  'The',
#  'government',
#  'includes',
#  'money',
#  'spent',
#  '*',
#  'on',
#  'residential',
#  'renovation',
#  ';',
#  'Dodge',
#  'does',
#  "n't",
#  '*?*',
#  '.',
#  'Last',
#  'year',
#  ',',
#  'government',
#  'payments',
#  'to',
#  'farmers',
#  'slipped',
#  'to',
#  'less',
#  'than',
#  '$',
#  '14.5',
#  'billion',
#  '*U*',
#  'from',
#  'a',
#  'record',
#  '$',
#  '16.7',
#  'billion',
#  '*U*',
#  'in',
#  '1987',
#  '.',
#  'Heritage',
#  'owns',
#  'and',
#  'operates',
#  'television',
#  'and',
#  'radio',
#  'stations',
#  'and',
#  'in-store',
#  'advertising',
#  'and',
#  'promotion',
#  'programs',
#  '.',
#  'Japan',
#  "'s",
#  'domestic',
#  'sales',
#  'of',
#  'cars',
#  ',',
#  'trucks',
#  'and',
#  'buses',
#  'in',
#  'October',
#  'rose',
#  '18',
#  '%',
#  'from',
#  'a',
#  'year',
#  'earlier',
#  'to',
#  '500,004',
#  'units',
#  ',',
#  'a',
#  'record',
#  'for',
#  'the',
#  'month',
#  ',',
#  'the',
#  'Japan',
#  'Automobile',
#  'Dealers',
#  "'",
#  'Association',
#  'said',
#  '0',
#  '*T*-1',
#  '.',
#  'U.S.',
#  'chip',
#  'makers',
#  'are',
#  'facing',
#  'continued',
#  'slack',
#  'demand',
#  'following',
#  'a',
#  'traditionally',
#  'slow',
#  'summer',
#  '.',
#  'She',
#  'was',
#  'an',
#  'unstinting',
#  'teacher',
#  'who',
#  '*T*-80',
#  'won',
#  'laurels',
#  'and',
#  'inspired',
#  'students',
#  ',',
#  'but',
#  'she',
#  'will',
#  'probably',
#  'never',
#  'teach',
#  'again',
#  '.',
#  'The',
#  'aerospace',
#  ',',
#  'automotive',
#  'supply',
#  ',',
#  'electronics',
#  'and',
#  'printing-press',
#  'concern',
#  'also',
#  'indicated',
#  'that',
#  'the',
#  'first',
#  'half',
#  'of',
#  'fiscal',
#  '1990',
#  'could',
#  'be',
#  'rough',
#  '.',
#  'W.R.',
#  'Grace',
#  'holds',
#  'three',
#  'of',
#  'Grace',
#  'Energy',
#  "'s",
#  'seven',
#  'board',
#  'seats',
#  '.',
#  'The',
#  'oldest',
#  'bell-ringing',
#  'group',
#  'in',
#  'the',
#  'country',
#  ',',
#  'the',
#  'Ancient',
#  'Society',
#  'of',
#  'College',
#  'Youths',
#  ',',
#  'founded',
#  '*',
#  'in',
#  '1637',
#  ',',
#  'remains',
#  'male-only',
#  ',',
#  'a',
#  'fact',
#  'that',
#  '*T*-230',
#  "'s",
#  'particularly',
#  'galling',
#  'to',
#  'women',
#  'because',
#  'the',
#  'group',
#  'is',
#  'the',
#  'sole',
#  'source',
#  'of',
#  'ringers',
#  'for',
#  'Britain',
#  "'s",
#  'most',
#  'prestigious',
#  'churches',
#  ',',
#  'St.',
#  'Paul',
#  "'s",
#  'Cathedral',
#  'and',
#  'Westminster',
#  'Abbey',
#  '.',
#  'Taiwan',
#  'has',
#  'improved',
#  'its',
#  'standing',
#  'with',
#  'the',
#  'U.S.',
#  'by',
#  '*-2',
#  'initialing',
#  'a',
#  'bilateral',
#  'copyright',
#  'agreement',
#  ',',
#  'amending',
#  'its',
#  'trademark',
#  ...]

# %%
# Unique words comprising the vocabulary
V = set([tup[0] for tup in train_tagged_words])
print(len(V))
# Out:
# 12109

# %%
# Unique POS tags assigned in the words in the universal penn tree bank
T = set([tup[1] for tup in train_tagged_words])

# %%
# List of all POS tags
print(T)
# Out:
# {'X', 'ADJ', 'DET', 'VERB', 'NOUN', 'ADP', '.', 'PRON', 'ADV', 'CONJ', 'PRT', 'NUM'}

# %% [markdown]
# ### Emission Probabilities

# %%
# Return 
# 1. the number of times a word appears given a certain POS tag
# 2. Number of words having the given POS tag
def word_given_tag(word, pos_tag, train_bag = train_tagged_words):
    word_tag_combo = [tup for tup in train_bag if tup[1] == pos_tag]
    return(len([tup for tup in word_tag_combo if tup[0] == word]), len(word_tag_combo))

# %%
# Below is an example for an imperative verb. Such verbs are typically at the beginning of a sentence and used for 
# ordering

# Since the training data is unlikely to have the word or exists with a low probability, the probability of the correct
# POS tag getting selected is low

# %%
word_given_tag('Show', 'NOUN')
# Out:
# (1, 27423)

# %%
word_given_tag('Show', 'VERB')
# Out:
# (0, 12885)

# %%
word_given_tag('Brunswick', 'NOUN')
# Out:
# (1, 27423)

# %% [markdown]
# ### Transition Probabilities

# %%
# Transition probabilities are assigned based on the likelihood of a word taking up a certain POS tag by virtue of 
# the prev word POS tag

# %%
def tag2_given_tag1(tag2, tag1, train_bag = train_tagged_words):
    tags = [tup[1] for tup in train_bag]
    count_tag2 = len([t for t in tags if t == tag1])
    count_tag2_given_tag1 = 0
    for index in range(len(tags)-1):
        if tags[index] == tag1 and tags[index+1] == tag2:
            count_tag2_given_tag1 += 1
    return(count_tag2_given_tag1, count_tag2)

# %%
print(tag2_given_tag1(tag2='NOUN', tag1='DET'))
# Out:
# (5302, 8284)

# %% [markdown]
# ### Capture transition probabilities in a t x t matrix

# %%
#### Create t x t transition matrix of tags to capture the transition probabilities
tags_matrix = np.zeros((len(T), len(T)), dtype='float32')

# %%
for index1, tag1 in enumerate(T):
    for index2, tag2 in enumerate(T):
        tag2_given_tag1_cnts = tag2_given_tag1(tag2, tag1)
        tags_matrix[index1, index2] = tag2_given_tag1_cnts[0]/ tag2_given_tag1_cnts[1]

# %%
tags_matrix
# Out:
# array([[7.64818341e-02, 1.65710635e-02, 5.51306568e-02, 2.03632891e-01,
#         6.13448061e-02, 1.42925426e-01, 1.63798600e-01, 5.60866781e-02,
#         2.51752716e-02, 1.03569152e-02, 1.85787126e-01, 2.70873168e-03],
#        [2.13921349e-02, 6.66447282e-02, 5.10120112e-03, 1.23416157e-02,
#         6.96725368e-01, 7.89863393e-02, 6.53282851e-02, 6.58219506e-04,
#         4.60753683e-03, 1.69491526e-02, 1.08606219e-02, 2.04048045e-02],
#        [4.55094166e-02, 2.04973444e-01, 5.31144394e-03, 3.83872539e-02,
#         6.40028954e-01, 9.05359723e-03, 1.79864801e-02, 3.74215352e-03,
#         1.23128919e-02, 4.82858537e-04, 2.41429268e-04, 2.19700634e-02],
#        [2.18005434e-01, 6.46488145e-02, 1.33100510e-01, 1.69188976e-01,
#         1.10904150e-01, 9.04928222e-02, 3.53123769e-02, 3.62436958e-02,
#         8.25766400e-02, 5.58789307e-03, 3.11214589e-02, 2.28172299e-02],
#        [2.91361269e-02, 1.22889541e-02, 1.33099956e-02, 1.47977978e-01,
#         2.64631867e-01, 1.76275387e-01, 2.39178792e-01, 4.92287474e-03,
#         1.68836378e-02, 4.19356003e-02, 4.38318215e-02, 9.62695573e-03],
#        [3.40288915e-02, 1.05296947e-01, 3.26377749e-01, 8.23970046e-03,
#         3.21776360e-01, 1.72284637e-02, 3.94863561e-02, 6.91278726e-02,
#         1.31621184e-02, 8.56072758e-04, 1.49812736e-03, 6.29213452e-02],
#        [2.66234931e-02, 4.49721180e-02, 1.73502430e-01, 8.85051265e-02,
#         2.23151639e-01, 9.11135077e-02, 9.38118398e-02, 6.53894618e-02,
#         5.20777106e-02, 5.79240881e-02, 2.33855005e-03, 8.05000886e-02],
#        [9.28189456e-02, 7.48663098e-02, 9.54927411e-03, 4.80901450e-01,
#         2.11229950e-01, 2.29182579e-02, 4.12528664e-02, 8.02139007e-03,
#         3.39954160e-02, 4.96562244e-03, 1.22230714e-02, 7.25744851e-03],
#        [2.35880390e-02, 1.30232558e-01, 6.71096370e-02, 3.44518274e-01,
#         3.08970101e-02, 1.19601332e-01, 1.36877075e-01, 1.56146176e-02,
#         8.10631216e-02, 6.31229253e-03, 1.36212623e-02, 3.05647831e-02],
#        [7.97747541e-03, 1.16846554e-01, 1.21539183e-01, 1.53918341e-01,
#         3.49131852e-01, 5.44345379e-02, 3.42562161e-02, 5.86579069e-02,
#         5.58423288e-02, 4.69263265e-04, 4.69263270e-03, 4.22336943e-02],
#        [1.34030730e-02, 8.63027126e-02, 1.00359596e-01, 4.02745992e-01,
#         2.42562935e-01, 2.15756781e-02, 4.15168367e-02, 1.89604443e-02,
#         1.01340311e-02, 2.28832942e-03, 1.63452106e-03, 5.85158542e-02],
#        [2.06660718e-01, 3.41956578e-02, 3.27088917e-03, 1.75438598e-02,
#         3.55337501e-01, 3.47903669e-02, 1.18346713e-01, 1.48676778e-03,
#         2.97353556e-03, 1.33809103e-02, 2.79512331e-02, 1.84061855e-01]],
#       dtype=float32)

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index = list(T))

# %%
tags_df
# Out:
#              X       ADJ       DET      VERB      NOUN       ADP         .  \
# X     0.076482  0.016571  0.055131  0.203633  0.061345  0.142925  0.163799
# ADJ   0.021392  0.066645  0.005101  0.012342  0.696725  0.078986  0.065328
# DET   0.045509  0.204973  0.005311  0.038387  0.640029  0.009054  0.017986
# VERB  0.218005  0.064649  0.133101  0.169189  0.110904  0.090493  0.035312
# NOUN  0.029136  0.012289  0.013310  0.147978  0.264632  0.176275  0.239179
# ADP   0.034029  0.105297  0.326378  0.008240  0.321776  0.017228  0.039486
# .     0.026623  0.044972  0.173502  0.088505  0.223152  0.091114  0.093812
# PRON  0.092819  0.074866  0.009549  0.480901  0.211230  0.022918  0.041253
# ADV   0.023588  0.130233  0.067110  0.344518  0.030897  0.119601  0.136877
# CONJ  0.007977  0.116847  0.121539  0.153918  0.349132  0.054435  0.034256
# PRT   0.013403  0.086303  0.100360  0.402746  0.242563  0.021576  0.041517
# NUM   0.206661  0.034196  0.003271  0.017544  0.355338  0.034790  0.118347
#
#           PRON       ADV      CONJ       PRT       NUM
# X     0.056087  0.025175  0.010357  0.185787  0.002709
# ADJ   0.000658  0.004608  0.016949  0.010861  0.020405
# DET   0.003742  0.012313  0.000483  0.000241  0.021970
# VERB  0.036244  0.082577  0.005588  0.031121  0.022817
# NOUN  0.004923  0.016884  0.041936  0.043832  0.009627
# ADP   0.069128  0.013162  0.000856  0.001498  0.062921
# .     0.065389  0.052078  0.057924  0.002339  0.080500
# PRON  0.008021  0.033995  0.004966  0.012223  0.007257
# ADV   0.015615  0.081063  0.006312  0.013621  0.030565
# CONJ  0.058658  0.055842  0.000469  0.004693  0.042234
# PRT   0.018960  0.010134  0.002288  0.001635  0.058516
# NUM   0.001487  0.002974  0.013381  0.027951  0.184062

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic

def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))

    print(T)
    
    for key, word in enumerate(words):

        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)

            pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# Running Viterbi algorithm on test set

# %%
# list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# %%
start = time.time()
tagged_seq = Viterbi(test_tagged_words[:])
end = time.time()
difference = end-start
# Out:
# ['X', 'ADJ', 'DET', 'VERB', 'NOUN', 'ADP', '.', 'PRON', 'ADV', 'CONJ', 'PRT', 'NUM']

# %%
print(tagged_seq)
# Out:
# [('For', 'ADP'), ('the', 'DET'), ('Agency', 'NOUN'), ('for', 'ADP'), ('International', 'NOUN'), ('Development', 'NOUN'), (',', '.'), ('appropriators', 'NOUN'), ('approved', 'VERB'), ('$', '.'), ('200', 'NUM'), ('million', 'NUM'), ('*U*', 'X'), ('in', 'ADP'), ('secondary', 'ADJ'), ('loan', 'NOUN'), ('guarantees', 'NOUN'), ('under', 'ADP'), ('an', 'DET'), ('expanded', 'VERB'), ('trade', 'VERB'), ('credit', 'NOUN'), ('insurance', 'NOUN'), ('program', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('total', 'ADJ'), ('loan', 'NOUN'), ('guarantees', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('Overseas', 'X'), ('Private', 'ADJ'), ('Investment', 'NOUN'), ('Corp.', 'NOUN'), ('are', 'VERB'), ('increased', 'VERB'), ('*-3', 'X'), ('by', 'ADP'), ('$', '.'), ('40', 'NUM'), ('million', 'NUM'), ('*U*', 'X'), ('over', 'ADP'), ('fiscal', 'ADJ'), ('1989', 'NUM'), ('as', 'ADP'), ('part', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('same', 'ADJ'), ('Poland', 'NOUN'), ('package', 'NOUN'), ('.', '.'), ('The', 'DET'), ('market', 'NOUN'), ('is', 'VERB'), ('just', 'ADV'), ('becoming', 'VERB'), ('more', 'ADV'), ('efficient', 'ADJ'), ('.', '.'), ("''", '.'), ('Moscow', 'NOUN'), ('has', 'VERB'), ('settled', 'VERB'), ('pre-1917', 'X'), ('debts', 'NOUN'), ('with', 'ADP'), ('other', 'ADJ'), ('countries', 'NOUN'), ('in', 'ADP'), ('recent', 'ADJ'), ('years', 'NOUN'), ('at', 'ADP'), ('less', 'ADJ'), ('than', 'ADP'), ('face', 'NOUN'), ('value', 'NOUN'), ('.', '.'), ('``', '.'), ('Unemployment', 'X'), ('continues', 'VERB'), ('at', 'ADP'), ('a', 'DET'), ('relatively', 'ADV'), ('low', 'ADJ'), ('level', 'NOUN'), (',', '.'), ('*', 'X'), ('providing', 'VERB'), ('a', 'DET'), ('sense', 'NOUN'), ('of', 'ADP'), ('job', 'NOUN'), ('security', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('a', 'DET'), ('low', 'ADJ'), ('inflation', 'NOUN'), ('rate', 'NOUN'), ('has', 'VERB'), ('kept', 'VERB'), ('the', 'DET'), ('purchasing', 'NOUN'), ('power', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('weekly', 'ADJ'), ('paycheck', 'X'), ('reasonably', 'X'), ('strong', 'ADJ'), ('.', '.'), ("''", '.'), ('At', 'ADP'), ('the', 'DET'), ('same', 'ADJ'), ('time', 'NOUN'), (',', '.'), ('though', 'ADP'), (',', '.'), ('he', 'PRON'), ('chastised', 'VERB'), ('the', 'DET'), ('media', 'NOUN'), ('for', 'ADP'), ('*', 'X'), ('paying', 'VERB'), ('such', 'ADJ'), ('close', 'NOUN'), ('attention', 'NOUN'), ('to', 'PRT'), ('Japanese', 'ADJ'), ('investment', 'NOUN'), ('when', 'ADV'), ('other', 'ADJ'), ('foreign', 'ADJ'), ('countries', 'NOUN'), (',', '.'), ('notably', 'ADV'), ('Britain', 'NOUN'), (',', '.'), ('are', 'VERB'), ('acquiring', 'VERB'), ('more', 'ADV'), ('American', 'ADJ'), ('assets', 'NOUN'), ('*T*-1', 'X'), ('.', '.'), ('*-1', 'X'), ('Funded', 'X'), ('*-2', 'X'), ('by', 'ADP'), ('a', 'DET'), ('$', '.'), ('1', 'NUM'), ('million', 'NUM'), ('*U*', 'X'), ('gift', 'NOUN'), ('from', 'ADP'), ('Tokio', 'X'), ('Marine', 'NOUN'), ('&', 'CONJ'), ('Fire', 'NOUN'), ('Insurance', 'NOUN'), (',', '.'), ('the', 'DET'), ('service', 'NOUN'), ('will', 'VERB'), ('follow', 'VERB'), ('Japanese', 'ADJ'), ('medical', 'ADJ'), ('protocols', 'X'), (',', '.'), ('including', 'VERB'), ('emphasis', 'NOUN'), ('on', 'ADP'), ('preventative', 'X'), ('medicine', 'NOUN'), ('.', '.'), ('On', 'ADP'), ('the', 'DET'), ('other', 'ADJ'), ('hand', 'NOUN'), (',', '.'), ('had', 'VERB'), ('it', 'PRON'), ('existed', 'X'), ('then', 'ADV'), (',', '.'), ('Cray', 'NOUN'), ('Computer', 'NOUN'), ('would', 'VERB'), ('have', 'VERB'), ('incurred', 'VERB'), ('a', 'DET'), ('$', '.'), ('20.5', 'X'), ('million', 'NUM'), ('*U*', 'X'), ('loss', 'NOUN'), ('.', '.'), ('``', '.'), ('The', 'DET'), ('disturbing', 'ADJ'), ('thing', 'NOUN'), ('about', 'ADP'), ('this', 'DET'), ('abortion', 'NOUN'), ('issue', 'NOUN'), ('is', 'VERB'), ('that', 'ADP'), ('the', 'DET'), ('debate', 'NOUN'), ('has', 'VERB'), ('become', 'VERB'), ('polarized', 'X'), ('*-1', 'X'), (',', '.'), ('so', 'ADV'), ('that', 'ADP'), ('no', 'DET'), ('mechanism', 'NOUN'), ('*ICH*-2', 'X'), ('exists', 'X'), ("''", '.'), ('for', 'ADP') ...

# %%
# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j]

# %%
accuracy = len(check)/len(tagged_seq)
print(accuracy)
# Out:
# 0.9148810693925693

# %%
# Incorrectly tagged cases

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]

# %%
incorrect_tagged_cases
# Out:
# [[('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('the', 'DET'), (('Overseas', 'X'), ('Overseas', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('settled', 'VERB'), (('pre-1917', 'X'), ('pre-1917', 'ADJ'))],
#  [('``', '.'), (('Unemployment', 'X'), ('Unemployment', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('weekly', 'ADJ'), (('paycheck', 'X'), ('paycheck', 'NOUN'))],
#  [('paycheck', 'NOUN'), (('reasonably', 'X'), ('reasonably', 'ADV'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('*-1', 'X'), (('Funded', 'X'), ('Funded', 'VERB'))],
#  [('from', 'ADP'), (('Tokio', 'X'), ('Tokio', 'NOUN'))],
#  [('medical', 'ADJ'), (('protocols', 'X'), ('protocols', 'NOUN'))],
#  [('on', 'ADP'), (('preventative', 'X'), ('preventative', 'ADJ'))],
#  [('it', 'PRON'), (('existed', 'X'), ('existed', 'VERB'))],
#  [('$', '.'), (('20.5', 'X'), ('20.5', 'NUM'))],
#  [('become', 'VERB'), (('polarized', 'X'), ('polarized', 'VERB'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('*ICH*-2', 'X'), (('exists', 'X'), ('exists', 'VERB'))],
#  [('a', 'DET'), (('middle', 'NOUN'), ('middle', 'ADJ'))],
#  [('.', '.'), (('Though', 'X'), ('Though', 'ADP'))],
#  [('prospective', 'ADJ'), (('acquirers', 'X'), ('acquirers', 'NOUN'))],
#  [("n't", 'ADV'), (('noticed', 'X'), ('noticed', 'VERB'))],
#  [('totaled', 'VERB'), (('154.2', 'X'), ('154.2', 'NUM'))],
#  [('Since', 'ADP'), (('chalk', 'X'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'X'), ('touched', 'VERB'))],
#  [('touched', 'VERB'), (('slate', 'X'), ('slate', 'NOUN'))],
#  [(',', '.'), (('schoolchildren', 'X'), ('schoolchildren', 'NOUN'))],
#  [('a', 'DET'), (('Catch-22', 'X'), ('Catch-22', 'NOUN'))],
#  [('on', 'ADP'), (('cross-border', 'X'), ('cross-border', 'ADJ'))],
#  [('of', 'ADP'), (('emigres', 'X'), ('emigres', 'NOUN'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'X'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('publicly', 'ADV'), (('apologizing', 'X'), ('apologizing', 'VERB'))],
#  [('*', 'X'), (('indulging', 'X'), ('indulging', 'VERB'))],
#  [('From', 'ADP'), (('1953', 'X'), ('1953', 'NUM'))],
#  [('to', 'PRT'), (('1955', 'X'), ('1955', 'NUM'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('had', 'VERB'), (('pre-existing', 'X'), ('pre-existing', 'ADJ'))],
#  [('or', 'CONJ'), (('addiction', 'X'), ('addiction', 'NOUN'))],
#  [('gaining', 'VERB'), (('1,200', 'X'), ('1,200', 'NUM'))],
#  [('Jack', 'NOUN'), (('Mogavero', 'X'), ('Mogavero', 'NOUN'))],
#  [(',', '.'), (('Piscataway', 'X'), ('Piscataway', 'NOUN'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'X'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('exploit', 'X'), ('exploit', 'VERB'))],
#  [('exploit', 'VERB'), (('brief', 'VERB'), ('brief', 'ADJ'))],
#  [('great', 'ADJ'), (('reds', 'X'), ('reds', 'NOUN'))],
#  [('the', 'DET'), (('Rhone', 'X'), ('Rhone', 'NOUN'))],
#  [('price', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('$', '.'), (('133.7', 'X'), ('133.7', 'NUM'))],
#  [('$', '.'), (('94', 'X'), ('94', 'NUM'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('she', 'PRON'), (('copied', 'X'), ('copied', 'VERB'))],
#  [('two', 'NUM'), (('octogenarians', 'X'), ('octogenarians', 'NOUN'))],
#  [('a', 'DET'),
#   (('sometimes-exhausting', 'X'), ('sometimes-exhausting', 'ADJ'))],
#  [('bells', 'NOUN'), (('sounding', 'X'), ('sounding', 'VERB'))],
#  [('many', 'ADJ'), (('belfries', 'X'), ('belfries', 'NOUN'))],
#  [('East', 'NOUN'), (('Anglia', 'X'), ('Anglia', 'NOUN'))],
#  [('of', 'ADP'), (('manmade-fiber', 'X'), ('manmade-fiber', 'ADJ'))],
#  [('$', '.'), (('405', 'X'), ('405', 'NUM'))],
#  [('*T*-102', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('Maxwell', 'NOUN'), (('Communication', 'X'), ('Communication', 'NOUN'))],
#  [('net', 'ADJ'), (('importer', 'X'), ('importer', 'NOUN'))],
#  [('to', 'PRT'), (('last', 'ADJ'), ('last', 'VERB'))],
#  [('ShareData', 'NOUN'), (('develops', 'X'), ('develops', 'VERB'))],
#  [('and', 'CONJ'), (('markets', 'NOUN'), ('markets', 'VERB'))],
#  [('markets', 'VERB'), (('low-cost', 'X'), ('low-cost', 'ADJ'))],
#  [('House', 'NOUN'), (('waived', 'X'), ('waived', 'VERB'))],
#  [('in', 'ADP'), (('supplemental', 'X'), ('supplemental', 'ADJ'))],
#  [('and', 'CONJ'), (('anti-drug', 'X'), ('anti-drug', 'ADJ'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('a', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('to', 'PRT'), (('red-flag', 'X'), ('red-flag', 'VERB'))],
#  [('the', 'DET'),
#   (('computer-generated', 'X'), ('computer-generated', 'ADJ'))],
#  [('by', 'ADP'), (('certified', 'X'), ('certified', 'ADJ'))],
#  [('certified', 'ADJ'), (('mail', 'X'), ('mail', 'NOUN'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('bills', 'NOUN'), (('containing', 'X'), ('containing', 'VERB'))],
#  [(',', '.'), (('alternatively', 'X'), ('alternatively', 'ADV'))],
#  [('to', 'PRT'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('their', 'PRON'), (('intrusions', 'X'), ('intrusions', 'NOUN'))],
#  [('on', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('thus', 'ADV'), (('void', 'X'), ('void', 'ADJ'))],
#  [('R.', 'NOUN'), (('Sloan', 'X'), ('Sloan', 'NOUN'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('$', '.'), (('43.875', 'X'), ('43.875', 'NUM'))],
#  [("n't", 'ADV'), (('mind', 'NOUN'), ('mind', 'VERB'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'X'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('also', 'ADV'), (('helps', 'X'), ('helps', 'VERB'))],
#  [('the', 'DET'), (('reluctance', 'X'), ('reluctance', 'NOUN'))],
#  [('farm', 'NOUN'), (('lobbies', 'X'), ('lobbies', 'NOUN'))],
#  [('daily', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('of', 'ADP'), (('133.8', 'X'), ('133.8', 'NUM'))],
#  [('$', '.'), (('2.47', 'X'), ('2.47', 'NUM'))],
#  [('up', 'ADV'), (('7.4', 'X'), ('7.4', 'NUM'))],
#  [('$', '.'), (('2.30', 'X'), ('2.30', 'NUM'))],
#  [('final', 'ADJ'), (('modification', 'X'), ('modification', 'NOUN'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('$', '.'), (('13.625', 'X'), ('13.625', 'NUM'))],
#  [('*-37', 'X'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('power', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('wield', 'X'), ('wield', 'VERB'))],
#  [('.', '.'), (('Muzzling', 'X'), ('Muzzling', 'ADJ'))],
#  [('``', '.'), (('blindfold', 'X'), ('blindfold', 'NOUN'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('*-2', 'X'), (('recommending', 'X'), ('recommending', 'VERB'))],
#  [('``', '.'), (('Anything', 'X'), ('Anything', 'NOUN'))],
#  [('Anything', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('how', 'ADV'), (('about', 'ADP'), ('about', 'PRT'))],
#  [("''", '.'), (('quips', 'X'), ('quips', 'VERB'))],
#  [('of', 'ADP'), (('Northampton', 'X'), ('Northampton', 'NOUN'))],
#  [('morphogenetic', 'ADJ'), (('protein', 'X'), ('protein', 'NOUN'))],
#  [('.', '.'), (('Fundamentalists', 'X'), ('Fundamentalists', 'NOUN'))],
#  [('including', 'VERB'), (('air', 'VERB'), ('air', 'NOUN'))],
#  [('air', 'NOUN'), (('bags', 'X'), ('bags', 'NOUN'))],
#  [('in', 'ADP'), (('front', 'NOUN'), ('front', 'ADJ'))],
#  [('improved', 'VERB'), (('side-crash', 'X'), ('side-crash', 'ADJ'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('alleged', 'VERB'), (('workplace', 'X'), ('workplace', 'NOUN'))],
#  [('a', 'DET'), (('word-processing', 'X'), ('word-processing', 'NOUN'))],
#  [('*', 'X'), (('Legend', 'X'), ('Legend', 'NOUN'))],
#  [('of', 'ADP'), (('multinational', 'X'), ('multinational', 'ADJ'))],
#  [('the', 'DET'), (('Iran-Contra', 'X'), ('Iran-Contra', 'NOUN'))],
#  [('a', 'DET'), (('wheel-loader', 'X'), ('wheel-loader', 'ADJ'))],
#  [('wheel-loader', 'ADJ'),
#   (('manufacturing', 'VERB'), ('manufacturing', 'NOUN'))],
#  [('in', 'ADP'), (('Heidelberg', 'X'), ('Heidelberg', 'NOUN'))],
#  [(',', '.'), (('drink', 'NOUN'), ('drink', 'VERB'))],
#  [('and', 'CONJ'), (('desultory', 'X'), ('desultory', 'ADJ'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('Yeargin', 'NOUN'), (('distinguished', 'X'), ('distinguished', 'VERB'))],
#  [('distinguished', 'VERB'), (('herself', 'X'), ('herself', 'PRON'))],
#  [('teaching', 'NOUN'), (('approaches', 'X'), ('approaches', 'NOUN'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('to', 'PRT'), (('pair', 'X'), ('pair', 'VERB'))],
#  [('using', 'VERB'), (('college-bowl', 'X'), ('college-bowl', 'NOUN'))],
#  [('type', 'NOUN'), (('competitions', 'X'), ('competitions', 'NOUN'))],
#  [('international', 'ADJ'), (('coffee', 'X'), ('coffee', 'NOUN'))],
#  [('Also', 'ADV'), (('spurring', 'X'), ('spurring', 'VERB'))],
#  [('diaper', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('with', 'ADP'), (('Velcro', 'X'), ('Velcro', 'NOUN'))],
#  [('fasteners', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('safety', 'NOUN'), (('pins', 'VERB'), ('pins', 'NOUN'))],
#  [('their', 'PRON'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('and', 'CONJ'), (('finance', 'NOUN'), ('finance', 'VERB'))],
#  [('selling', 'VERB'), (('non-core', 'X'), ('non-core', 'ADJ'))],
#  [('it', 'PRON'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('and', 'CONJ'), (('platinum', 'X'), ('platinum', 'NOUN'))],
#  [('have', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('was', 'VERB'), (('appropriated', 'X'), ('appropriated', 'VERB'))],
#  [('--', '.'), (('twice', 'X'), ('twice', 'ADV'))],
#  [('twice', 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('a', 'DET'), (('Johnson-era', 'X'), ('Johnson-era', 'NOUN'))],
#  [('creation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-2', 'X'), (('mandates', 'X'), ('mandates', 'VERB'))],
#  [('*-1', 'X'), (('noncompetitively', 'X'), ('noncompetitively', 'ADV'))],
#  [('very', 'ADV'), (('concerned', 'X'), ('concerned', 'VERB'))],
#  [('*T*-1', 'X'), (('Wilfred', 'X'), ('Wilfred', 'NOUN'))],
#  [('J.', 'NOUN'), (('Corrigan', 'X'), ('Corrigan', 'NOUN'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('take', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('``', '.'), (('derivatives', 'X'), ('derivatives', 'NOUN'))],
#  [('times', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('underlying', 'ADJ'), ('underlying', 'VERB'))],
#  [('adding', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [("'", 'PRT'), (('binders', 'X'), ('binders', 'NOUN'))],
#  [('$', '.'), (('93.9', 'X'), ('93.9', 'NUM'))],
#  [('$', '.'), (('1.19', 'X'), ('1.19', 'NUM'))],
#  [('$', '.'), (('92.9', 'X'), ('92.9', 'NUM'))],
#  [('$', '.'), (('1.18', 'X'), ('1.18', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('.', '.'), (('Demand', 'X'), ('Demand', 'NOUN'))],
#  [('but', 'CONJ'), (('due', 'ADJ'), ('due', 'ADV'))],
#  [(',', '.'), (('overseas', 'ADV'), ('overseas', 'ADJ'))],
#  [('the', 'DET'), (('apparent', 'X'), ('apparent', 'ADJ'))],
#  [('apparent', 'ADJ'), (('slowing', 'VERB'), ('slowing', 'NOUN'))],
#  [('David', 'NOUN'), (('Berson', 'X'), ('Berson', 'NOUN'))],
#  [('on', 'ADP'), (('single-family', 'NOUN'), ('single-family', 'ADJ'))],
#  [("n't", 'ADV'), (('estimate', 'NOUN'), ('estimate', 'VERB'))],
#  [('a', 'DET'), (('razor-thin', 'X'), ('razor-thin', 'ADJ'))],
#  [('a', 'DET'), (('fledgling', 'X'), ('fledgling', 'NOUN'))],
#  [('to', 'PRT'), (('depend', 'X'), ('depend', 'VERB'))],
#  [('and', 'CONJ'), (('longevity', 'X'), ('longevity', 'NOUN'))],
#  [('IRS', 'NOUN'), (('rarely', 'X'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', 'X'), ('acted', 'VERB'))],
#  [('``', '.'), (('deplorable', 'X'), ('deplorable', 'ADJ'))],
#  [('but', 'CONJ'), (('brushed', 'X'), ('brushed', 'VERB'))],
#  [('off', 'PRT'), (('talk', 'VERB'), ('talk', 'NOUN'))],
#  [('*', 'X'), (('renewing', 'X'), ('renewing', 'VERB'))],
#  [('the', 'DET'), (('insurgents', 'X'), ('insurgents', 'NOUN'))],
#  [('0', 'X'), (('total', 'VERB'), ('total', 'ADJ'))],
#  [('were', 'VERB'), (('topped', 'X'), ('topped', 'VERB'))],
#  [('the', 'DET'), (('16.5', 'X'), ('16.5', 'NUM'))],
#  [('contradict', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('-LRB-', '.'), (('technically', 'X'), ('technically', 'ADV'))],
#  [('a', 'DET'), (('limitation', 'X'), ('limitation', 'NOUN'))],
#  [('short', 'ADJ'), (('leash', 'X'), ('leash', 'NOUN'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'X'), ('triple', 'ADV'))],
#  [('a', 'DET'), (('Washington-based', 'X'), ('Washington-based', 'ADJ'))],
#  [('to', 'PRT'), (('sue', 'X'), ('sue', 'VERB'))],
#  [('$', '.'), (('777', 'X'), ('777', 'NUM'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('rose', 'VERB'), (('1.20', 'X'), ('1.20', 'NUM'))],
#  [('$', '.'), (('1.14', 'X'), ('1.14', 'NUM'))],
#  [('considerable', 'ADJ'), (('skill', 'X'), ('skill', 'NOUN'))],
#  [('of', 'ADP'), (('2163.2', 'X'), ('2163.2', 'NUM'))],
#  [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('Lane', 'NOUN'), (('dreamed', 'X'), ('dreamed', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'X'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'X'), ('shop', 'NOUN'))],
#  [('expensive', 'ADJ'), (('high-rise', 'X'), ('high-rise', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'X'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('to', 'PRT'), (('A.C.', 'X'), ('A.C.', 'NOUN'))],
#  [('A.C.', 'NOUN'), (('Nielsen', 'X'), ('Nielsen', 'NOUN'))],
#  [('*', 'X'), (('Having', 'X'), ('Having', 'VERB'))],
#  [('a', 'DET'), (('supportive', 'X'), ('supportive', 'ADJ'))],
#  [('supportive', 'ADJ'), (('element', 'X'), ('element', 'NOUN'))],
#  [('Richard', 'NOUN'), (('Breeden', 'X'), ('Breeden', 'NOUN'))],
#  [('circuit', 'NOUN'), (('breakers', 'X'), ('breakers', 'NOUN'))],
#  [('breakers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('rose', 'VERB'), (('87.5', 'X'), ('87.5', 'NUM'))],
#  [('$', '.'), (('38.875', 'X'), ('38.875', 'NUM'))],
#  [('frozen', 'VERB'), (('noodles', 'X'), ('noodles', 'NOUN'))],
#  [('and', 'CONJ'), (('pre-cooked', 'X'), ('pre-cooked', 'ADJ'))],
#  [('pre-cooked', 'ADJ'), (('pasta', 'X'), ('pasta', 'NOUN'))],
#  [('in', 'ADP'), (('Clive', 'X'), ('Clive', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('P.', 'NOUN'), (('Smaby', 'X'), ('Smaby', 'NOUN'))],
#  [('of', 'ADP'), (('Smaby', 'X'), ('Smaby', 'NOUN'))],
#  [('questionable', 'ADJ'), (('properties', 'X'), ('properties', 'NOUN'))],
#  [('.', '.'), (('INTER-TEL', 'X'), ('INTER-TEL', 'NOUN'))],
#  [('a', 'DET'), (('cosmetic', 'NOUN'), ('cosmetic', 'ADJ'))],
#  [('S.', 'NOUN'), (('Gelles', 'X'), ('Gelles', 'NOUN'))],
#  [('of', 'ADP'), (('Wertheim', 'X'), ('Wertheim', 'NOUN'))],
#  [('Wertheim', 'NOUN'), (('Schroder', 'X'), ('Schroder', 'NOUN'))],
#  [('and', 'CONJ'), (('entertaining', 'X'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'), (('confrontational', 'X'), ('confrontational', 'ADJ'))],
#  [('be', 'VERB'), (('refunded', 'X'), ('refunded', 'VERB'))],
#  [('a', 'DET'), (('shareholder-rights', 'X'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'X'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [('you', 'PRON'), (('bothered', 'X'), ('bothered', 'VERB'))],
#  [('the', 'DET'), (('inverse', 'X'), ('inverse', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('on', 'ADP'), (('66.5', 'X'), ('66.5', 'NUM'))],
#  [('factors', 'NOUN'), (('affecting', 'X'), ('affecting', 'VERB'))],
#  [('Anthony', 'NOUN'), (('Hazell', 'X'), ('Hazell', 'NOUN'))],
#  [('district', 'NOUN'), (('auditor', 'X'), ('auditor', 'NOUN'))],
#  [("n't", 'ADV'), (('vested', 'X'), ('vested', 'VERB'))],
#  [('of', 'ADP'), (('seconds', 'X'), ('seconds', 'NOUN'))],
#  [('a', 'DET'), (('low-tech', 'X'), ('low-tech', 'ADJ'))],
#  [('can', 'VERB'), (('catch', 'NOUN'), ('catch', 'VERB'))],
#  [("'s", 'PRT'), (('fancy', 'X'), ('fancy', 'NOUN'))],
#  [('a', 'DET'), (('strategic', 'X'), ('strategic', 'ADJ'))],
#  [('strategic', 'ADJ'), (('fit', 'ADJ'), ('fit', 'NOUN'))],
#  [('*', 'X'), (('servicing', 'NOUN'), ('servicing', 'VERB'))],
#  [('opportunities', 'NOUN'), (('arise', 'X'), ('arise', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('more', 'ADV'), (('cumbersome', 'X'), ('cumbersome', 'ADJ'))],
#  [('wild', 'ADJ'), (('stock-price', 'X'), ('stock-price', 'NOUN'))],
#  [(':', '.'), (('day-care', 'X'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('previously', 'ADV'), (('spurned', 'X'), ('spurned', 'VERB'))],
#  [('those', 'DET'), (('pressed', 'X'), ('pressed', 'VERB'))],
#  [('are', 'VERB'), (('implemented', 'X'), ('implemented', 'VERB'))],
#  [(':', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [(',', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('investment', 'NOUN'), (('focus', 'VERB'), ('focus', 'NOUN'))],
#  [('and', 'CONJ'), (('3', 'NUM'), ('3', 'X'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('their', 'PRON'), (('monopoly', 'X'), ('monopoly', 'NOUN'))],
#  [('yield', 'VERB'), (('7.422', 'X'), ('7.422', 'NUM'))],
#  [('So', 'ADV'), (('crunch', 'X'), ('crunch', 'NOUN'))],
#  [(',', '.'), (('crunch', 'X'), ('crunch', 'NOUN'))],
#  [(',', '.'), (('crunch', 'X'), ('crunch', 'NOUN'))],
#  [(',', '.'), (('bang', 'X'), ('bang', 'NOUN'))],
#  [(',', '.'), (('bang', 'X'), ('bang', 'NOUN'))],
#  [(',', '.'), (('bang', 'X'), ('bang', 'NOUN'))],
#  [('from', 'ADP'), (('above', 'ADP'), ('above', 'ADV'))],
#  [('very', 'ADV'), (('obvious', 'X'), ('obvious', 'ADJ'))],
#  [('obvious', 'ADJ'), (('exit', 'X'), ('exit', 'NOUN'))],
#  [('at', 'ADP'), (('prayer', 'X'), ('prayer', 'NOUN'))],
#  [('has', 'VERB'), (('minted', 'X'), ('minted', 'VERB'))],
#  [('of', 'ADP'), (('millionaires', 'X'), ('millionaires', 'NOUN'))],
#  [('their', 'PRON'), (('20s', 'X'), ('20s', 'NUM'))],
#  [('and', 'CONJ'), (('30s', 'X'), ('30s', 'NUM'))],
#  [('in', 'ADP'), (('replacement-car', 'X'), ('replacement-car', 'NOUN'))],
#  [('replacement-car', 'NOUN'), (('rentals', 'X'), ('rentals', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', 'X'), ('accidents', 'NOUN'))],
#  [('for', 'ADP'),
#   (('computer-system-design', 'X'), ('computer-system-design', 'ADJ'))],
#  [('the', 'DET'), (('more-advanced', 'X'), ('more-advanced', 'ADJ'))],
#  [('386', 'NUM'), (('microprocessor', 'X'), ('microprocessor', 'NOUN'))],
#  [('four', 'NUM'), (('megabytes', 'X'), ('megabytes', 'NOUN'))],
#  [('a', 'DET'), (('100-megabyte', 'X'), ('100-megabyte', 'ADJ'))],
#  [('100-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('$', '.'), (('5,699', 'X'), ('5,699', 'NUM'))],
#  [('$', '.'), (('6,799', 'X'), ('6,799', 'NUM'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'ll", 'VERB'), (('weather', 'NOUN'), ('weather', 'VERB'))],
#  [('any', 'DET'), (('storm', 'X'), ('storm', 'NOUN'))],
#  [("''", '.'), (('Citizens', 'X'), ('Citizens', 'NOUN'))],
#  [('in', 'ADP'), (('Peninsula', 'X'), ('Peninsula', 'NOUN'))],
#  [("'s", 'PRT'), (('floral', 'X'), ('floral', 'ADJ'))],
#  [('$', '.'), (('70-a-share', 'X'), ('70-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('buy-back', 'NOUN'), ('buy-back', 'ADJ'))],
#  [('*-2', 'X'), (('pressed', 'X'), ('pressed', 'VERB'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('still', 'ADV'), (('concerned', 'X'), ('concerned', 'VERB'))],
#  [('disturbing', 'ADJ'), (('developments', 'X'), ('developments', 'NOUN'))],
#  [('continuing', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('*T*-42', 'X'), (('saved', 'X'), ('saved', 'VERB'))],
#  [('to', 'PRT'), (('reclaim', 'X'), ('reclaim', 'VERB'))],
#  [('``', '.'), (('mortgaged', 'X'), ('mortgaged', 'VERB'))],
#  [('under', 'ADP'), (('price-support', 'X'), ('price-support', 'ADJ'))],
#  [('latest', 'ADJ'), (('compilation', 'X'), ('compilation', 'NOUN'))],
#  [('open', 'ADJ'), (('direct-investment', 'X'), ('direct-investment', 'ADJ'))],
#  [('he', 'PRON'), (('blames', 'X'), ('blames', 'VERB'))],
#  [('an', 'DET'), (('actor', 'X'), ('actor', 'NOUN'))],
#  [('the', 'DET'), (('inheritor', 'X'), ('inheritor', 'NOUN'))],
#  [('of', 'ADP'), (('Charlie', 'X'), ('Charlie', 'NOUN'))],
#  [("'s", 'PRT'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('not', 'ADV'), (('volunteer', 'X'), ('volunteer', 'NOUN'))],
#  [('volunteer', 'NOUN'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('--', '.'), (('teetering', 'X'), ('teetering', 'VERB'))],
#  [('on', 'ADP'), (('insolvency', 'X'), ('insolvency', 'NOUN'))],
#  [('a', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('an', 'DET'), (('avid', 'X'), ('avid', 'ADJ'))],
#  [('avid', 'ADJ'), (('fan', 'X'), ('fan', 'NOUN'))],
#  [('Toronto', 'NOUN'), (('cable', 'X'), ('cable', 'NOUN'))],
#  [('People', 'NOUN'), (('close', 'VERB'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('guarantee', 'NOUN'), ('guarantee', 'VERB'))],
#  [('estimated', 'VERB'),
#   (('seven-million-ton', 'X'), ('seven-million-ton', 'ADJ'))],
#  [('seven-million-ton', 'ADJ'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'ADJ'), ('acid', 'NOUN'))],
#  [('on', 'ADP'), (('50.1', 'X'), ('50.1', 'NUM'))],
#  [('A.', 'NOUN'), (('DiLoreto', 'X'), ('DiLoreto', 'NOUN'))],
#  [('metal', 'NOUN'), (('container', 'X'), ('container', 'NOUN'))],
#  [('succeeding', 'VERB'), (('Delmont', 'X'), ('Delmont', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('.', '.'), (('FreudToy', 'X'), ('FreudToy', 'NOUN'))],
#  [('a', 'DET'), (('pillow', 'X'), ('pillow', 'NOUN'))],
#  [('the', 'DET'), (('likeness', 'X'), ('likeness', 'NOUN'))],
#  [('of', 'ADP'), (('Sigmund', 'X'), ('Sigmund', 'NOUN'))],
#  [('Sigmund', 'NOUN'), (('Freud', 'X'), ('Freud', 'NOUN'))],
#  [('$', '.'), (('24.95', 'X'), ('24.95', 'NUM'))],
#  [('*U*', 'X'), (('tool', 'X'), ('tool', 'NOUN'))],
#  [('for', 'ADP'), (('do-it-yourself', 'X'), ('do-it-yourself', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('$', '.'), (('1.82', 'X'), ('1.82', 'NUM'))],
#  [('$', '.'), (('84.29', 'X'), ('84.29', 'NUM'))],
#  [('the', 'DET'), (('impending', 'VERB'), ('impending', 'ADJ'))],
#  [('impending', 'ADJ'), (('attack', 'VERB'), ('attack', 'NOUN'))],
#  [("n't", 'ADV'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('ring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('a', 'DET'), (('longtime', 'X'), ('longtime', 'NOUN'))],
#  [('a', 'DET'), (('scholar', 'X'), ('scholar', 'NOUN'))],
#  [('rumored', 'VERB'), (('target', 'VERB'), ('target', 'NOUN'))],
#  [('been', 'VERB'), (('enormously', 'X'), ('enormously', 'ADV'))],
#  [('enormously', 'ADV'), (('frustrating', 'X'), ('frustrating', 'VERB'))],
#  [('computer', 'NOUN'), (('science', 'X'), ('science', 'NOUN'))],
#  [('was', 'VERB'), (('raring', 'X'), ('raring', 'ADJ'))],
#  [('to', 'PRT'), (('invent', 'X'), ('invent', 'VERB'))],
#  [('another', 'DET'), (('Walkman', 'X'), ('Walkman', 'NOUN'))],
#  [('--', '.'), (('IRAs', 'X'), ('IRAs', 'NOUN'))],
#  [("n't", 'ADV'), (('segmenting', 'X'), ('segmenting', 'VERB'))],
#  [('to', 'PRT'), (('equip', 'X'), ('equip', 'VERB'))],
#  [('with', 'ADP'), (('lap-shoulder', 'X'), ('lap-shoulder', 'ADJ'))],
#  [('for', 'ADP'), (('rear', 'X'), ('rear', 'ADJ'))],
#  [('was', 'VERB'), (('soliciting', 'X'), ('soliciting', 'VERB'))],
#  [('sell', 'VERB'), (('TXO', 'X'), ('TXO', 'NOUN'))],
#  [('free', 'ADJ'), (('trip', 'X'), ('trip', 'NOUN'))],
#  [('*-5', 'X'), (('mindful', 'X'), ('mindful', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('from', 'ADP'), (('malignant', 'X'), ('malignant', 'ADJ'))],
#  [('malignant', 'ADJ'), (('mesothelioma', 'X'), ('mesothelioma', 'NOUN'))],
#  [('and', 'CONJ'), (('asbestosis', 'X'), ('asbestosis', 'NOUN'))],
#  [(',', '.'), (('16.9', 'X'), ('16.9', 'NUM'))],
#  [('0', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('with', 'ADP'), (('17.4', 'X'), ('17.4', 'NUM'))],
#  [('and', 'CONJ'), (('18.6', 'X'), ('18.6', 'NUM'))],
#  [('.', '.'), (('Tokyu', 'X'), ('Tokyu', 'NOUN'))],
#  [('the', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('the', 'DET'), (('verge', 'X'), ('verge', 'NOUN'))],
#  [('most', 'ADV'), (('favored', 'VERB'), ('favored', 'ADJ'))],
#  [('abortionist', 'NOUN'), (('accidentally', 'X'), ('accidentally', 'ADV'))],
#  [('it', 'PRON'), (('enabled', 'X'), ('enabled', 'VERB'))],
#  [('buy', 'VERB'), (('jam', 'X'), ('jam', 'NOUN'))],
#  [(',', '.'), (('cocoa', 'X'), ('cocoa', 'NOUN'))],
#  [('other', 'ADJ'), (('war-rationed', 'X'), ('war-rationed', 'ADJ'))],
#  [('war-rationed', 'ADJ'), (('goodies', 'X'), ('goodies', 'NOUN'))],
#  [('the', 'DET'), (('reins', 'X'), ('reins', 'NOUN'))],
#  [('have', 'VERB'), (('competed', 'X'), ('competed', 'VERB'))],
#  [('and', 'CONJ'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('would', 'VERB'), (('disclose', 'X'), ('disclose', 'VERB'))],
#  [("'s", 'PRT'), (('cost', 'VERB'), ('cost', 'NOUN'))],
#  [('$', '.'), (('1.50', 'X'), ('1.50', 'NUM'))],
#  [('Henry', 'NOUN'), (('I.', 'X'), ('I.', 'NOUN'))],
#  [('alleged', 'ADJ'), (('improper', 'X'), ('improper', 'ADJ'))],
#  [('improper', 'ADJ'), (('use', 'VERB'), ('use', 'NOUN'))],
#  [('to', 'PRT'), (('crack', 'NOUN'), ('crack', 'VERB'))],
#  [('crack', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('January', 'NOUN'), (('platinum', 'X'), ('platinum', 'NOUN'))],
#  [('was', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('$', '.'), (('5.70', 'X'), ('5.70', 'NUM'))],
#  [('$', '.'), (('494.50', 'X'), ('494.50', 'NUM'))]]

# %% [markdown]
# ### Solve the problem of unknown words

# %% [markdown]
# ### Part-1

# %%
# Based on the analysis of incorrectly tagged cases, there are quite a few unknown words, all of which are 
# getting a random tag assigned. And the random tag turns out to be the first tag in the set of tags obtained by 
# consolidating POS tags of all words in the training data set

# %% [markdown]
# ### Why does the Viterbi algorithm choose a random tag on encountering an unknown word

# %%
# The random tag turns out to be the first tag in the set of tags obtained by 
# consolidating POS tags of all words in the training data set

# %%
# The analysis also presents the following key findings:
#     1. Emission probability for all such unknown words is 0, because of this when multiplied, 
#        transition probability is ignored
#     2. Hence, a random POS tag as explained above gets assigned
#     3. For this reason, we will ignore emission probability and base the assignment of POS tag on transition 
#        probability only

# %%
# The above implementation of Viterbi algorithm is modified slightly to consider the discussed changes into
# consideration

# %%
# Viterbi Heuristic
def Viterbi_transition(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        trans_prob = []
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities

            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p  
            p.append(state_probability)
            trans_prob.append(transition_p)
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 

        # Check if the emission probability for the word against each POS tag is zero, this means that word
        # is missing from the training set, in such a case, ignore the emission probability and consider
        # only the transition probability
         
        if pmax == 0:
            pmax = max(trans_prob)
            state_max = T[trans_prob.index(pmax)]

        state.append(state_max)
    return list(zip(words, state))

# %%
# Execute the algorithm to find the new accuracy

# %%
start = time.time()
tagged_seq = Viterbi_transition(test_tagged_words[:])
end = time.time()
difference = end-start

# %%
print(tagged_seq)
# Out:
# [('For', 'ADP'), ('the', 'DET'), ('Agency', 'NOUN'), ('for', 'ADP'), ('International', 'NOUN'), ('Development', 'NOUN'), (',', '.'), ('appropriators', 'NOUN'), ('approved', 'VERB'), ('$', '.'), ('200', 'NUM'), ('million', 'NUM'), ('*U*', 'X'), ('in', 'ADP'), ('secondary', 'ADJ'), ('loan', 'NOUN'), ('guarantees', 'NOUN'), ('under', 'ADP'), ('an', 'DET'), ('expanded', 'VERB'), ('trade', 'VERB'), ('credit', 'NOUN'), ('insurance', 'NOUN'), ('program', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('total', 'ADJ'), ('loan', 'NOUN'), ('guarantees', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('Overseas', 'NOUN'), ('Private', 'ADJ'), ('Investment', 'NOUN'), ('Corp.', 'NOUN'), ('are', 'VERB'), ('increased', 'VERB'), ('*-3', 'X'), ('by', 'ADP'), ('$', '.'), ('40', 'NUM'), ('million', 'NUM'), ('*U*', 'X'), ('over', 'ADP'), ('fiscal', 'ADJ'), ('1989', 'NUM'), ('as', 'ADP'), ('part', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('same', 'ADJ'), ('Poland', 'NOUN'), ('package', 'NOUN'), ('.', '.'), ('The', 'DET'), ('market', 'NOUN'), ('is', 'VERB'), ('just', 'ADV'), ('becoming', 'VERB'), ('more', 'ADV'), ('efficient', 'ADJ'), ('.', '.'), ("''", '.'), ('Moscow', 'NOUN'), ('has', 'VERB'), ('settled', 'VERB'), ('pre-1917', 'X'), ('debts', 'NOUN'), ('with', 'ADP'), ('other', 'ADJ'), ('countries', 'NOUN'), ('in', 'ADP'), ('recent', 'ADJ'), ('years', 'NOUN'), ('at', 'ADP'), ('less', 'ADJ'), ('than', 'ADP'), ('face', 'NOUN'), ('value', 'NOUN'), ('.', '.'), ('``', '.'), ('Unemployment', 'NOUN'), ('continues', 'VERB'), ('at', 'ADP'), ('a', 'DET'), ('relatively', 'ADV'), ('low', 'ADJ'), ('level', 'NOUN'), (',', '.'), ('*', 'X'), ('providing', 'VERB'), ('a', 'DET'), ('sense', 'NOUN'), ('of', 'ADP'), ('job', 'NOUN'), ('security', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('a', 'DET'), ('low', 'ADJ'), ('inflation', 'NOUN'), ('rate', 'NOUN'), ('has', 'VERB'), ('kept', 'VERB'), ('the', 'DET'), ('purchasing', 'NOUN'), ('power', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('weekly', 'ADJ'), ('paycheck', 'NOUN'), ('reasonably', 'NOUN'), ('strong', 'ADJ'), ('.', '.'), ("''", '.'), ('At', 'ADP'), ('the', 'DET'), ('same', 'ADJ'), ('time', 'NOUN'), (',', '.'), ('though', 'ADP'), (',', '.'), ('he', 'PRON'), ('chastised', 'VERB'), ('the', 'DET'), ('media', 'NOUN'), ('for', 'ADP'), ('*', 'X'), ('paying', 'VERB'), ('such', 'ADJ'), ('close', 'NOUN'), ('attention', 'NOUN'), ('to', 'PRT'), ('Japanese', 'ADJ'), ('investment', 'NOUN'), ('when', 'ADV'), ('other', 'ADJ'), ('foreign', 'ADJ'), ('countries', 'NOUN'), (',', '.'), ('notably', 'ADV'), ('Britain', 'NOUN'), (',', '.'), ('are', 'VERB'), ('acquiring', 'VERB'), ('more', 'ADV'), ('American', 'ADJ'), ('assets', 'NOUN'), ('*T*-1', 'X'), ('.', '.'), ('*-1', 'X'), ('Funded', 'VERB'), ('*-2', 'X'), ('by', 'ADP'), ('a', 'DET'), ('$', '.'), ('1', 'NUM'), ('million', 'NUM'), ('*U*', 'X'), ('gift', 'NOUN'), ('from', 'ADP'), ('Tokio', 'DET'), ('Marine', 'NOUN'), ('&', 'CONJ'), ('Fire', 'NOUN'), ('Insurance', 'NOUN'), (',', '.'), ('the', 'DET'), ('service', 'NOUN'), ('will', 'VERB'), ('follow', 'VERB'), ('Japanese', 'ADJ'), ('medical', 'ADJ'), ('protocols', 'NOUN'), (',', '.'), ('including', 'VERB'), ('emphasis', 'NOUN'), ('on', 'ADP'), ('preventative', 'DET'), ('medicine', 'NOUN'), ('.', '.'), ('On', 'ADP'), ('the', 'DET'), ('other', 'ADJ'), ('hand', 'NOUN'), (',', '.'), ('had', 'VERB'), ('it', 'PRON'), ('existed', 'VERB'), ('then', 'ADV'), (',', '.'), ('Cray', 'NOUN'), ('Computer', 'NOUN'), ('would', 'VERB'), ('have', 'VERB'), ('incurred', 'VERB'), ('a', 'DET'), ('$', '.'), ('20.5', 'NOUN'), ('million', 'NUM'), ('*U*', 'X'), ('loss', 'NOUN'), ('.', '.'), ('``', '.'), ('The', 'DET'), ('disturbing', 'ADJ'), ('thing', 'NOUN'), ('about', 'ADP'), ('this', 'DET'), ('abortion', 'NOUN'), ('issue', 'NOUN'), ('is', 'VERB'), ('that', 'ADP'), ('the', 'DET'), ('debate', 'NOUN'), ('has', 'VERB'), ('become', 'VERB'), ('polarized', 'X'), ('*-1', 'X'), (',', '.'), ('so', 'ADV'), ('that', 'ADP'), ('no', 'DET'), ('mechanism', 'NOUN'), ('*ICH*-2', 'X'), ('exists', 'VERB ...

# %% [markdown]
# ### Evaluating tagging accuracy

# %%
# accuracy
check = [i for i, j in zip(tagged_seq, test_run_base) if i == j]

# %%
accuracy = len(check)/len(tagged_seq)
print(accuracy)
# Out:
# 0.9388637703951248

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
# As compared to 91.48% accuracy, we have now obtained 93.88% accuracy which is an improvement almost 2.5%

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]

# %%
incorrect_tagged_cases
# Out:
# [[('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('Overseas', 'NOUN'), (('Private', 'ADJ'), ('Private', 'NOUN'))],
#  [('settled', 'VERB'), (('pre-1917', 'X'), ('pre-1917', 'ADJ'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('paycheck', 'NOUN'), (('reasonably', 'NOUN'), ('reasonably', 'ADV'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('from', 'ADP'), (('Tokio', 'DET'), ('Tokio', 'NOUN'))],
#  [('on', 'ADP'), (('preventative', 'DET'), ('preventative', 'ADJ'))],
#  [('$', '.'), (('20.5', 'NOUN'), ('20.5', 'NUM'))],
#  [('become', 'VERB'), (('polarized', 'X'), ('polarized', 'VERB'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('a', 'DET'), (('middle', 'NOUN'), ('middle', 'ADJ'))],
#  [('.', '.'), (('Though', 'NOUN'), ('Though', 'ADP'))],
#  [('totaled', 'VERB'), (('154.2', 'X'), ('154.2', 'NUM'))],
#  [('Since', 'ADP'), (('chalk', 'DET'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('first', 'ADV'), (('touched', 'NOUN'), ('touched', 'VERB'))],
#  [('on', 'ADP'), (('cross-border', 'DET'), ('cross-border', 'ADJ'))],
#  [('of', 'ADP'), (('emigres', 'DET'), ('emigres', 'NOUN'))],
#  [('which', 'DET'), (('*T*-133', 'NOUN'), ('*T*-133', 'X'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'NOUN'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('From', 'ADP'), (('1953', 'DET'), ('1953', 'NUM'))],
#  [('to', 'PRT'), (('1955', 'VERB'), ('1955', 'NUM'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('had', 'VERB'), (('pre-existing', 'X'), ('pre-existing', 'ADJ'))],
#  [('gaining', 'VERB'), (('1,200', 'X'), ('1,200', 'NUM'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'VERB'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-253', 'DET'), ('*T*-253', 'X'))],
#  [('price', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('$', '.'), (('133.7', 'NOUN'), ('133.7', 'NUM'))],
#  [('$', '.'), (('94', 'NOUN'), ('94', 'NUM'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('who', 'PRON'), (('*T*-222', 'VERB'), ('*T*-222', 'X'))],
#  [('a', 'DET'),
#   (('sometimes-exhausting', 'NOUN'), ('sometimes-exhausting', 'ADJ'))],
#  [('bells', 'NOUN'), (('sounding', 'NOUN'), ('sounding', 'VERB'))],
#  [('of', 'ADP'), (('manmade-fiber', 'DET'), ('manmade-fiber', 'ADJ'))],
#  [('$', '.'), (('405', 'NOUN'), ('405', 'NUM'))],
#  [('What', 'PRON'), (('*T*-102', 'VERB'), ('*T*-102', 'X'))],
#  [('*T*-102', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('to', 'PRT'), (('last', 'ADJ'), ('last', 'VERB'))],
#  [('ShareData', 'NOUN'), (('develops', 'NOUN'), ('develops', 'VERB'))],
#  [('and', 'CONJ'), (('markets', 'NOUN'), ('markets', 'VERB'))],
#  [('markets', 'VERB'), (('low-cost', 'NOUN'), ('low-cost', 'ADJ'))],
#  [('House', 'NOUN'), (('waived', 'NOUN'), ('waived', 'VERB'))],
#  [('in', 'ADP'), (('supplemental', 'DET'), ('supplemental', 'ADJ'))],
#  [('and', 'CONJ'), (('anti-drug', 'NOUN'), ('anti-drug', 'ADJ'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('a', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-128', 'VERB'), ('*T*-128', 'X'))],
#  [('who', 'PRON'), (('*T*-129', 'VERB'), ('*T*-129', 'X'))],
#  [('the', 'DET'),
#   (('computer-generated', 'NOUN'), ('computer-generated', 'ADJ'))],
#  [('by', 'ADP'), (('certified', 'DET'), ('certified', 'ADJ'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('bills', 'NOUN'), (('containing', 'NOUN'), ('containing', 'VERB'))],
#  [(',', '.'), (('alternatively', 'NOUN'), ('alternatively', 'ADV'))],
#  [('to', 'PRT'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('their', 'PRON'), (('intrusions', 'VERB'), ('intrusions', 'NOUN'))],
#  [('on', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('thus', 'ADV'), (('void', 'VERB'), ('void', 'ADJ'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('$', '.'), (('43.875', 'NOUN'), ('43.875', 'NUM'))],
#  [("n't", 'ADV'), (('mind', 'NOUN'), ('mind', 'VERB'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('and', 'CONJ'), (('shopped', 'NOUN'), ('shopped', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('daily', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('of', 'ADP'), (('133.8', 'DET'), ('133.8', 'NUM'))],
#  [('$', '.'), (('2.47', 'NOUN'), ('2.47', 'NUM'))],
#  [('up', 'ADV'), (('7.4', 'VERB'), ('7.4', 'NUM'))],
#  [('$', '.'), (('2.30', 'NOUN'), ('2.30', 'NUM'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('$', '.'), (('13.625', 'NOUN'), ('13.625', 'NUM'))],
#  [('*-37', 'X'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('power', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Muzzling', 'NOUN'), ('Muzzling', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('Anything', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('how', 'ADV'), (('about', 'ADP'), ('about', 'PRT'))],
#  [("''", '.'), (('quips', 'NOUN'), ('quips', 'VERB'))],
#  [('of', 'ADP'), (('Northampton', 'DET'), ('Northampton', 'NOUN'))],
#  [('including', 'VERB'), (('air', 'VERB'), ('air', 'NOUN'))],
#  [('air', 'NOUN'), (('bags', 'X'), ('bags', 'NOUN'))],
#  [('in', 'ADP'), (('front', 'NOUN'), ('front', 'ADJ'))],
#  [('improved', 'VERB'), (('side-crash', 'X'), ('side-crash', 'ADJ'))],
#  [('for', 'ADP'), (('alleged', 'ADJ'), ('alleged', 'VERB'))],
#  [('*', 'X'), (('Legend', 'VERB'), ('Legend', 'NOUN'))],
#  [('of', 'ADP'), (('multinational', 'DET'), ('multinational', 'ADJ'))],
#  [('a', 'DET'), (('wheel-loader', 'NOUN'), ('wheel-loader', 'ADJ'))],
#  [('in', 'ADP'), (('Heidelberg', 'DET'), ('Heidelberg', 'NOUN'))],
#  [(',', '.'), (('drink', 'NOUN'), ('drink', 'VERB'))],
#  [('and', 'CONJ'), (('desultory', 'NOUN'), ('desultory', 'ADJ'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('Yeargin', 'NOUN'), (('distinguished', 'NOUN'), ('distinguished', 'VERB'))],
#  [('distinguished', 'VERB'), (('herself', 'NOUN'), ('herself', 'PRON'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('pair', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('using', 'VERB'), (('college-bowl', 'X'), ('college-bowl', 'NOUN'))],
#  [('diaper', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('with', 'ADP'), (('Velcro', 'DET'), ('Velcro', 'NOUN'))],
#  [('fasteners', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('safety', 'NOUN'), (('pins', 'VERB'), ('pins', 'NOUN'))],
#  [('their', 'PRON'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('and', 'CONJ'), (('finance', 'NOUN'), ('finance', 'VERB'))],
#  [('selling', 'VERB'), (('non-core', 'X'), ('non-core', 'ADJ'))],
#  [('it', 'PRON'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('have', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('was', 'VERB'), (('appropriated', 'X'), ('appropriated', 'VERB'))],
#  [('--', '.'), (('twice', 'NOUN'), ('twice', 'ADV'))],
#  [('twice', 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('creation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*-1', 'X'), (('noncompetitively', 'VERB'), ('noncompetitively', 'ADV'))],
#  [('*T*-1', 'X'), (('Wilfred', 'VERB'), ('Wilfred', 'NOUN'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('take', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('times', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('underlying', 'ADJ'), ('underlying', 'VERB'))],
#  [('adding', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [("'", 'PRT'), (('binders', 'VERB'), ('binders', 'NOUN'))],
#  [('$', '.'), (('93.9', 'NOUN'), ('93.9', 'NUM'))],
#  [('$', '.'), (('1.19', 'NOUN'), ('1.19', 'NUM'))],
#  [('$', '.'), (('92.9', 'NOUN'), ('92.9', 'NUM'))],
#  [('$', '.'), (('1.18', 'NOUN'), ('1.18', 'NUM'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('but', 'CONJ'), (('due', 'ADJ'), ('due', 'ADV'))],
#  [(',', '.'), (('overseas', 'ADV'), ('overseas', 'ADJ'))],
#  [('the', 'DET'), (('apparent', 'NOUN'), ('apparent', 'ADJ'))],
#  [('apparent', 'ADJ'), (('slowing', 'VERB'), ('slowing', 'NOUN'))],
#  [('on', 'ADP'), (('single-family', 'NOUN'), ('single-family', 'ADJ'))],
#  [("n't", 'ADV'), (('estimate', 'NOUN'), ('estimate', 'VERB'))],
#  [('a', 'DET'), (('razor-thin', 'NOUN'), ('razor-thin', 'ADJ'))],
#  [('IRS', 'NOUN'), (('rarely', 'NOUN'), ('rarely', 'ADV'))],
#  [('rarely', 'ADV'), (('acted', 'NOUN'), ('acted', 'VERB'))],
#  [('``', '.'), (('deplorable', 'NOUN'), ('deplorable', 'ADJ'))],
#  [('but', 'CONJ'), (('brushed', 'NOUN'), ('brushed', 'VERB'))],
#  [('off', 'PRT'), (('talk', 'VERB'), ('talk', 'NOUN'))],
#  [('0', 'X'), (('total', 'VERB'), ('total', 'ADJ'))],
#  [('were', 'VERB'), (('topped', 'X'), ('topped', 'VERB'))],
#  [('the', 'DET'), (('16.5', 'NOUN'), ('16.5', 'NUM'))],
#  [('contradict', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('-LRB-', '.'), (('technically', 'NOUN'), ('technically', 'ADV'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'NOUN'), ('triple', 'ADV'))],
#  [('a', 'DET'), (('Washington-based', 'NOUN'), ('Washington-based', 'ADJ'))],
#  [('$', '.'), (('777', 'NOUN'), ('777', 'NUM'))],
#  [('the', 'DET'), (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('rose', 'VERB'), (('1.20', 'X'), ('1.20', 'NUM'))],
#  [('$', '.'), (('1.14', 'NOUN'), ('1.14', 'NUM'))],
#  [('of', 'ADP'), (('2163.2', 'DET'), ('2163.2', 'NUM'))],
#  [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('Lane', 'NOUN'), (('dreamed', 'NOUN'), ('dreamed', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'VERB'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'VERB'), ('shop', 'NOUN'))],
#  [('expensive', 'ADJ'), (('high-rise', 'NOUN'), ('high-rise', 'ADJ'))],
#  [('Oct.', 'NOUN'), (('2-8', 'NOUN'), ('2-8', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('to', 'PRT'), (('A.C.', 'VERB'), ('A.C.', 'NOUN'))],
#  [('A.C.', 'NOUN'), (('Nielsen', 'X'), ('Nielsen', 'NOUN'))],
#  [('a', 'DET'), (('supportive', 'NOUN'), ('supportive', 'ADJ'))],
#  [('breakers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-215', 'DET'), ('*T*-215', 'X'))],
#  [('rose', 'VERB'), (('87.5', 'X'), ('87.5', 'NUM'))],
#  [('$', '.'), (('38.875', 'NOUN'), ('38.875', 'NUM'))],
#  [('frozen', 'VERB'), (('noodles', 'X'), ('noodles', 'NOUN'))],
#  [('and', 'CONJ'), (('pre-cooked', 'NOUN'), ('pre-cooked', 'ADJ'))],
#  [('in', 'ADP'), (('Clive', 'DET'), ('Clive', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('of', 'ADP'), (('Smaby', 'DET'), ('Smaby', 'NOUN'))],
#  [('a', 'DET'), (('cosmetic', 'NOUN'), ('cosmetic', 'ADJ'))],
#  [('of', 'ADP'), (('Wertheim', 'DET'), ('Wertheim', 'NOUN'))],
#  [('and', 'CONJ'), (('entertaining', 'NOUN'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'),
#   (('confrontational', 'NOUN'), ('confrontational', 'ADJ'))],
#  [('be', 'VERB'), (('refunded', 'X'), ('refunded', 'VERB'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('on', 'ADP'), (('66.5', 'DET'), ('66.5', 'NUM'))],
#  [('factors', 'NOUN'), (('affecting', 'NOUN'), ('affecting', 'VERB'))],
#  [('of', 'ADP'), (('seconds', 'DET'), ('seconds', 'NOUN'))],
#  [('a', 'DET'), (('low-tech', 'NOUN'), ('low-tech', 'ADJ'))],
#  [('can', 'VERB'), (('catch', 'NOUN'), ('catch', 'VERB'))],
#  [("'s", 'PRT'), (('fancy', 'VERB'), ('fancy', 'NOUN'))],
#  [('a', 'DET'), (('strategic', 'NOUN'), ('strategic', 'ADJ'))],
#  [('*', 'X'), (('servicing', 'NOUN'), ('servicing', 'VERB'))],
#  [('opportunities', 'NOUN'), (('arise', 'NOUN'), ('arise', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('more', 'ADV'), (('cumbersome', 'VERB'), ('cumbersome', 'ADJ'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('those', 'DET'), (('pressed', 'NOUN'), ('pressed', 'VERB'))],
#  [('are', 'VERB'), (('implemented', 'X'), ('implemented', 'VERB'))],
#  [(':', '.'), (('1', 'NUM'), ('1', 'X'))],
#  [(',', '.'), (('2', 'NUM'), ('2', 'X'))],
#  [('investment', 'NOUN'), (('focus', 'VERB'), ('focus', 'NOUN'))],
#  [('and', 'CONJ'), (('3', 'NUM'), ('3', 'X'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('their', 'PRON'), (('monopoly', 'VERB'), ('monopoly', 'NOUN'))],
#  [('yield', 'VERB'), (('7.422', 'X'), ('7.422', 'NUM'))],
#  [('So', 'ADV'), (('crunch', 'VERB'), ('crunch', 'NOUN'))],
#  [('from', 'ADP'), (('above', 'ADP'), ('above', 'ADV'))],
#  [('very', 'ADV'), (('obvious', 'VERB'), ('obvious', 'ADJ'))],
#  [('obvious', 'ADJ'), (('exit', 'X'), ('exit', 'NOUN'))],
#  [('at', 'ADP'), (('prayer', 'DET'), ('prayer', 'NOUN'))],
#  [('has', 'VERB'), (('minted', 'X'), ('minted', 'VERB'))],
#  [('of', 'ADP'), (('millionaires', 'DET'), ('millionaires', 'NOUN'))],
#  [('their', 'PRON'), (('20s', 'VERB'), ('20s', 'NUM'))],
#  [('and', 'CONJ'), (('30s', 'NOUN'), ('30s', 'NUM'))],
#  [('in', 'ADP'), (('replacement-car', 'DET'), ('replacement-car', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', 'DET'), ('accidents', 'NOUN'))],
#  [('for', 'ADP'),
#   (('computer-system-design', 'DET'), ('computer-system-design', 'ADJ'))],
#  [('the', 'DET'), (('more-advanced', 'NOUN'), ('more-advanced', 'ADJ'))],
#  [('a', 'DET'), (('100-megabyte', 'NOUN'), ('100-megabyte', 'ADJ'))],
#  [('100-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('$', '.'), (('5,699', 'NOUN'), ('5,699', 'NUM'))],
#  [('$', '.'), (('6,799', 'NOUN'), ('6,799', 'NUM'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'ll", 'VERB'), (('weather', 'NOUN'), ('weather', 'VERB'))],
#  [('in', 'ADP'), (('Peninsula', 'DET'), ('Peninsula', 'NOUN'))],
#  [("'s", 'PRT'), (('floral', 'VERB'), ('floral', 'ADJ'))],
#  [('$', '.'), (('70-a-share', 'NOUN'), ('70-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('buy-back', 'NOUN'), ('buy-back', 'ADJ'))],
#  [('which', 'DET'), (('*T*-156', 'NOUN'), ('*T*-156', 'X'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('continuing', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('``', '.'), (('mortgaged', 'NOUN'), ('mortgaged', 'VERB'))],
#  [('under', 'ADP'), (('price-support', 'DET'), ('price-support', 'ADJ'))],
#  [('open', 'ADJ'),
#   (('direct-investment', 'NOUN'), ('direct-investment', 'ADJ'))],
#  [('of', 'ADP'), (('Charlie', 'DET'), ('Charlie', 'NOUN'))],
#  [("'s", 'PRT'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('not', 'ADV'), (('volunteer', 'VERB'), ('volunteer', 'NOUN'))],
#  [('volunteer', 'NOUN'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('--', '.'), (('teetering', 'NOUN'), ('teetering', 'VERB'))],
#  [('on', 'ADP'), (('insolvency', 'DET'), ('insolvency', 'NOUN'))],
#  [('a', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('an', 'DET'), (('avid', 'NOUN'), ('avid', 'ADJ'))],
#  [('People', 'NOUN'), (('close', 'VERB'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('guarantee', 'NOUN'), ('guarantee', 'VERB'))],
#  [('estimated', 'VERB'),
#   (('seven-million-ton', 'X'), ('seven-million-ton', 'ADJ'))],
#  [('seven-million-ton', 'ADJ'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'ADJ'), ('acid', 'NOUN'))],
#  [('on', 'ADP'), (('50.1', 'DET'), ('50.1', 'NUM'))],
#  [('succeeding', 'VERB'), (('Delmont', 'X'), ('Delmont', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('of', 'ADP'), (('Sigmund', 'DET'), ('Sigmund', 'NOUN'))],
#  [('$', '.'), (('24.95', 'NOUN'), ('24.95', 'NUM'))],
#  [('*U*', 'X'), (('tool', 'VERB'), ('tool', 'NOUN'))],
#  [('for', 'ADP'), (('do-it-yourself', 'DET'), ('do-it-yourself', 'ADJ'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('$', '.'), (('1.82', 'NOUN'), ('1.82', 'NUM'))],
#  [('$', '.'), (('84.29', 'NOUN'), ('84.29', 'NUM'))],
#  [('the', 'DET'), (('impending', 'VERB'), ('impending', 'ADJ'))],
#  [('impending', 'ADJ'), (('attack', 'VERB'), ('attack', 'NOUN'))],
#  [("n't", 'ADV'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('ring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('rumored', 'VERB'), (('target', 'VERB'), ('target', 'NOUN'))],
#  [('been', 'VERB'), (('enormously', 'X'), ('enormously', 'ADV'))],
#  [('was', 'VERB'), (('raring', 'X'), ('raring', 'ADJ'))],
#  [('with', 'ADP'), (('lap-shoulder', 'DET'), ('lap-shoulder', 'ADJ'))],
#  [('for', 'ADP'), (('rear', 'DET'), ('rear', 'ADJ'))],
#  [('was', 'VERB'), (('soliciting', 'X'), ('soliciting', 'VERB'))],
#  [('sell', 'VERB'), (('TXO', 'X'), ('TXO', 'NOUN'))],
#  [('*-5', 'X'), (('mindful', 'VERB'), ('mindful', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('from', 'ADP'), (('malignant', 'DET'), ('malignant', 'ADJ'))],
#  [(',', '.'), (('16.9', 'NOUN'), ('16.9', 'NUM'))],
#  [('0', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('with', 'ADP'), (('17.4', 'DET'), ('17.4', 'NUM'))],
#  [('and', 'CONJ'), (('18.6', 'NOUN'), ('18.6', 'NUM'))],
#  [('the', 'DET'), (('Soviet', 'ADJ'), ('Soviet', 'NOUN'))],
#  [('most', 'ADV'), (('favored', 'VERB'), ('favored', 'ADJ'))],
#  [('abortionist', 'NOUN'),
#   (('accidentally', 'NOUN'), ('accidentally', 'ADV'))],
#  [('buy', 'VERB'), (('jam', 'X'), ('jam', 'NOUN'))],
#  [('other', 'ADJ'), (('war-rationed', 'NOUN'), ('war-rationed', 'ADJ'))],
#  [('have', 'VERB'), (('competed', 'X'), ('competed', 'VERB'))],
#  [('and', 'CONJ'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('would', 'VERB'), (('disclose', 'X'), ('disclose', 'VERB'))],
#  [("'s", 'PRT'), (('cost', 'VERB'), ('cost', 'NOUN'))],
#  [('$', '.'), (('1.50', 'NOUN'), ('1.50', 'NUM'))],
#  [('alleged', 'ADJ'), (('improper', 'NOUN'), ('improper', 'ADJ'))],
#  [('improper', 'ADJ'), (('use', 'VERB'), ('use', 'NOUN'))],
#  [('to', 'PRT'), (('crack', 'NOUN'), ('crack', 'VERB'))],
#  [('crack', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('was', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))],
#  [('$', '.'), (('5.70', 'NOUN'), ('5.70', 'NUM'))],
#  [('$', '.'), (('494.50', 'NOUN'), ('494.50', 'NUM'))]]

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# Following are some words that were incorrectly tagged (due to the word missing in training data) &
# due to which it got randomly assigned "X" tag:
    
# 1. Overseas - NOUN
# 2. Unemployment - NOUN
# 3. paycheck - NOUN
# 4. Funded - VERB
# 5. existed - VERB

# were all incorrectly tagged into X which is the first POS tag in the set defined on the POS tags of all words in the
# training data set

# %% [markdown]
# ### Part 2:

# %%
# We notice that there is a good improvement in the accuracy. However, upon further analysis, there are still certain
# words getting an incorrect POS tag assigned due to a misleading transition probability

# %%
# To handle, these inaccuracies, we will define a few rules using the morphological structure of words which provide
# guidance on what the potential POS tag could be for the word

# %% [markdown]
# ### Which tag class do you think most unknown words belong to?

# %%
# It can be observed that most unknown words are nouns that have a starting letter in upper case. According
# to this, observation of training data and some of the other rules, the following function has been defined

# %%
def apply_morphological_rules(text):
    # Initialize a list where the updated POS tags can be captured
    new_list = []
    
    for i, tup in enumerate(text):

        # If the word is a 0, 1, 2, 3 which was assigned with a POS tag X, do not change it
        if tup[0] == '0' or tup[0] == '1' or tup[0] == '2' or tup[0] == '3':
            new_list.append((tup[0], 'X'))
            continue
        
        # If the first character of the word is an *, assign it with a POS tag of X
        if tup[0][0] == '*':
            new_list.append((tup[0], 'X'))
            continue
        
        # For an imperative verb such as SHOW which the algorithm consistently assigns incorrectly, 
        # assign it as a very
        if tup[0] in ['Show', 'Use', 'Give', 'Eat', 'Sleep']:
            new_list.append((tup[0], 'VERB'))
            continue
            
        # The word THEY is a pronoun regardless of the context in which it is used    
        if tup[0].lower() == 'they':
            new_list.append((tup[0], 'PRON'))
            continue
            
        # The word INSTEAD is a pronoun regardless of the context in which it is used
        if tup[0].lower() == 'instead':
            new_list.append((tup[0], 'ADV'))
            continue            
        
        # The word p.m is a pronoun regardless of the context in which it is used
        if tup[0] == 'p.m':
            new_list.append((tup[0], 'ADV'))
            continue 
        
        # If there is a 2 digit number preceded by a single quote, assign the NUM tag
        # Examples are '86 and '88
        if re.search("^'\d{2}", tup[0]) != None:
            new_list.append((tup[0], 'NUM'))
            continue
        
        # For patterns such as whole numbers of ddd, ddd, ddd or d:dd, assign the NUM tag
        if re.search('^\d+(\.|:|,|-)?\d{0,3}(,)?\d{0,3}$', tup[0]) != None:
            new_list.append((tup[0], 'NUM'))
            continue
        
        # For examples such as 1st, 2nd, 3rd, 4th, assign ADJ as the POS tag    
        if re.search('^\d+(nd|rd|st|th)$', tup[0]) != None:
            new_list.append((tup[0], 'ADJ'))
            continue
        
        # According to the language rules, most adverbs end with "ly"
        if re.search('^\w*ly$', tup[0]):    
            new_list.append((tup[0], 'ADV'))
            continue                 
        
        # According to the language rules, most verbs if not all end with "ed", such as jumped, turned
        if (re.search('^[\w]*ed$', tup[0]) and len(tup[0]) > 4):
            new_list.append((tup[0], 'VERB'))
            continue

        # handles phrases such as heavy-duty, direct-investment most of which are adjectives with very few exceptions
        if re.search('\w+-[a-z]+', tup[0]) != None:
            new_list.append((tup[0], 'ADJ'))
            continue
            
        # Words that are alphabetic and start with a capital letter are typically nouns
        # We want to ignore words such as It, By which are not nouns      
        if re.search('^[A-Z]+[a-z]*', tup[0]) and len(tup[0]) > 3:
            new_list.append((tup[0], 'NOUN'))
            continue
            
        new_list.append(tup)        
                            
    return(new_list)

# %% [markdown]
# Please note that the new function is being invoked on the output of the modified Viterbi algorithm

# %%
new_tagged_seq = apply_morphological_rules(tagged_seq)

# %% [markdown]
# ### Evaluating tagging accuracy

# %%
# accuracy
check = [i for i, j in zip(new_tagged_seq, test_run_base) if i == j]

# %%
accuracy = len(check)/len(new_tagged_seq)
print(accuracy)
# Out:
# 0.9496756437979162

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
# As compared to 91.48% accuracy, we have now obtained ~95% accuracy which is an improvement of almost 3.5%

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(new_tagged_seq, test_run_base)) if j[0]!=j[1]]

# %%
incorrect_tagged_cases
# Out:
# [[('expanded', 'VERB'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('settled', 'VERB'), (('pre-1917', 'X'), ('pre-1917', 'ADJ'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('the', 'DET'), (('weekly', 'ADV'), ('weekly', 'ADJ'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('Japanese', 'NOUN'), ('Japanese', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('more', 'ADJ'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('$', '.'), (('1', 'X'), ('1', 'NUM'))],
#  [('follow', 'VERB'), (('Japanese', 'NOUN'), ('Japanese', 'ADJ'))],
#  [('on', 'ADP'), (('preventative', 'DET'), ('preventative', 'ADJ'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('a', 'DET'), (('middle', 'NOUN'), ('middle', 'ADJ'))],
#  [('.', '.'), (('Though', 'NOUN'), ('Though', 'ADP'))],
#  [('.', '.'), (('Since', 'NOUN'), ('Since', 'ADP'))],
#  [('Since', 'ADP'), (('chalk', 'DET'), ('chalk', 'NOUN'))],
#  [('chalk', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [(':', '.'), (('What', 'NOUN'), ('What', 'PRON'))],
#  [('?', '.'), (('Moreover', 'NOUN'), ('Moreover', 'ADV'))],
#  [('of', 'ADP'), (('emigres', 'DET'), ('emigres', 'NOUN'))],
#  [('.', '.'), (('Among', 'NOUN'), ('Among', 'ADP'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'NOUN'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('.', '.'), (('From', 'NOUN'), ('From', 'ADP'))],
#  [('.', '.'), (('Some', 'NOUN'), ('Some', 'DET'))],
#  [('the', 'DET'), (('homeless', 'ADJ'), ('homeless', 'NOUN'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('price', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('.', '.'), (('That', 'NOUN'), ('That', 'DET'))],
#  [('.', '.'), (('When', 'NOUN'), ('When', 'ADV'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('bells', 'NOUN'), (('sounding', 'NOUN'), ('sounding', 'VERB'))],
#  [('.', '.'), (('What', 'NOUN'), ('What', 'PRON'))],
#  [('*T*-102', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('.', '.'), (('This', 'NOUN'), ('This', 'DET'))],
#  [('.', '.'), (('This', 'NOUN'), ('This', 'DET'))],
#  [('to', 'PRT'), (('last', 'ADJ'), ('last', 'VERB'))],
#  [('ShareData', 'NOUN'), (('develops', 'NOUN'), ('develops', 'VERB'))],
#  [('and', 'CONJ'), (('markets', 'NOUN'), ('markets', 'VERB'))],
#  [('in', 'ADP'), (('supplemental', 'DET'), ('supplemental', 'ADJ'))],
#  [('no', 'DET'), (('bearing', 'VERB'), ('bearing', 'NOUN'))],
#  [('our', 'PRON'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('work', 'NOUN'), (('force', 'VERB'), ('force', 'NOUN'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('.', '.'), (('Also', 'NOUN'), ('Also', 'ADV'))],
#  [('a', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('to', 'PRT'), (('red-flag', 'ADJ'), ('red-flag', 'VERB'))],
#  [('by', 'ADP'), (('certified', 'VERB'), ('certified', 'ADJ'))],
#  [('.', '.'), (('During', 'NOUN'), ('During', 'ADP'))],
#  [('to', 'PRT'), (('veto', 'NOUN'), ('veto', 'VERB'))],
#  [('bills', 'NOUN'), (('containing', 'NOUN'), ('containing', 'VERB'))],
#  [('to', 'PRT'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('their', 'PRON'), (('intrusions', 'VERB'), ('intrusions', 'NOUN'))],
#  [('on', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('thus', 'ADV'), (('void', 'VERB'), ('void', 'ADJ'))],
#  [(',', '.'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('closed', 'VERB'), (('unchanged', 'VERB'), ('unchanged', 'ADJ'))],
#  [("n't", 'ADV'), (('mind', 'NOUN'), ('mind', 'VERB'))],
#  [("''", '.'), (('Some', 'NOUN'), ('Some', 'DET'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('bank', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'s", 'PRT'), (('daily', 'ADV'), ('daily', 'ADJ'))],
#  [('daily', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [('*', 'X'), (('Excluding', 'NOUN'), ('Excluding', 'VERB'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('*-37', 'X'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('power', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('Dorrance', 'NOUN'), (('family', 'ADV'), ('family', 'NOUN'))],
#  [('the', 'DET'), (('troubled', 'VERB'), ('troubled', 'ADJ'))],
#  [('.', '.'), (('Muzzling', 'NOUN'), ('Muzzling', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('Anything', 'NOUN'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('how', 'ADV'), (('about', 'ADP'), ('about', 'PRT'))],
#  [("''", '.'), (('quips', 'NOUN'), ('quips', 'VERB'))],
#  [('including', 'VERB'), (('air', 'VERB'), ('air', 'NOUN'))],
#  [('air', 'NOUN'), (('bags', 'X'), ('bags', 'NOUN'))],
#  [('in', 'ADP'), (('front', 'NOUN'), ('front', 'ADJ'))],
#  [('.', '.'), (('While', 'NOUN'), ('While', 'ADP'))],
#  [('a', 'DET'), (('word-processing', 'ADJ'), ('word-processing', 'NOUN'))],
#  [('McAlpine', 'NOUN'), (('family', 'ADV'), ('family', 'NOUN'))],
#  [('of', 'ADP'), (('multinational', 'DET'), ('multinational', 'ADJ'))],
#  [('.', '.'), (('This', 'NOUN'), ('This', 'DET'))],
#  [('.', '.'), (('Last', 'NOUN'), ('Last', 'ADJ'))],
#  [(',', '.'), (('drink', 'NOUN'), ('drink', 'VERB'))],
#  [('and', 'CONJ'), (('desultory', 'NOUN'), ('desultory', 'ADJ'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('distinguished', 'VERB'), (('herself', 'NOUN'), ('herself', 'PRON'))],
#  [('*-1', 'X'), (('forcing', 'VERB'), ('forcing', 'ADJ'))],
#  [('pair', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('using', 'VERB'), (('college-bowl', 'ADJ'), ('college-bowl', 'NOUN'))],
#  [('*', 'X'), (('Also', 'NOUN'), ('Also', 'ADV'))],
#  [('diaper', 'NOUN'), (('covers', 'VERB'), ('covers', 'NOUN'))],
#  [('fasteners', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('safety', 'NOUN'), (('pins', 'VERB'), ('pins', 'NOUN'))],
#  [('its', 'PRON'), (('real-estate', 'ADJ'), ('real-estate', 'NOUN'))],
#  [('their', 'PRON'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('put', 'VERB'), (('in', 'ADP'), ('in', 'PRT'))],
#  [('several', 'ADJ'), (('hundred', 'VERB'), ('hundred', 'NUM'))],
#  [('and', 'CONJ'), (('finance', 'NOUN'), ('finance', 'VERB'))],
#  [('it', 'PRON'), (('off', 'PRT'), ('off', 'ADP'))],
#  [('have', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('--', '.'), (('twice', 'NOUN'), ('twice', 'ADV'))],
#  [('twice', 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('.', '.'), (('This', 'NOUN'), ('This', 'DET'))],
#  [('a', 'DET'), (('Johnson-era', 'ADJ'), ('Johnson-era', 'NOUN'))],
#  [('creation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('senior', 'ADJ'), (('Japanese', 'NOUN'), ('Japanese', 'ADJ'))],
#  [('``', '.'), (('Over', 'NOUN'), ('Over', 'ADP'))],
#  [('*T*-1', 'X'), (('Wilfred', 'VERB'), ('Wilfred', 'NOUN'))],
#  [('and', 'CONJ'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('chief', 'ADJ'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('take', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('.', '.'), (('This', 'NOUN'), ('This', 'DET'))],
#  [('times', 'NOUN'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('underlying', 'ADJ'), ('underlying', 'VERB'))],
#  [('adding', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('About', 'NOUN'), ('About', 'ADP'))],
#  [("'", 'PRT'), (('binders', 'VERB'), ('binders', 'NOUN'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('but', 'CONJ'), (('due', 'ADJ'), ('due', 'ADV'))],
#  [(',', '.'), (('overseas', 'ADV'), ('overseas', 'ADJ'))],
#  [('the', 'DET'), (('apparent', 'NOUN'), ('apparent', 'ADJ'))],
#  [('apparent', 'ADJ'), (('slowing', 'VERB'), ('slowing', 'NOUN'))],
#  [('until', 'ADP'), (('early', 'ADV'), ('early', 'ADJ'))],
#  [("n't", 'ADV'), (('estimate', 'NOUN'), ('estimate', 'VERB'))],
#  [('.', '.'), (('Until', 'NOUN'), ('Until', 'ADP'))],
#  [('``', '.'), (('deplorable', 'NOUN'), ('deplorable', 'ADJ'))],
#  [('off', 'PRT'), (('talk', 'VERB'), ('talk', 'NOUN'))],
#  [('0', 'X'), (('total', 'VERB'), ('total', 'ADJ'))],
#  [('contradict', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'NOUN'), ('triple', 'ADV'))],
#  [('committee', 'NOUN'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('.', '.'), (('Such', 'NOUN'), ('Such', 'ADJ'))],
#  [('last', 'ADJ'), (('half-hour', 'ADJ'), ('half-hour', 'NOUN'))],
#  [('To', 'PRT'), (('further', 'ADJ'), ('further', 'ADV'))],
#  [('further', 'ADV'), (('load', 'NOUN'), ('load', 'VERB'))],
#  [('highly', 'ADV'), (('improbable', 'VERB'), ('improbable', 'ADJ'))],
#  [("'s", 'PRT'), (('shop', 'VERB'), ('shop', 'NOUN'))],
#  [('Oct.', 'NOUN'), (('1', 'X'), ('1', 'NUM'))],
#  [('year', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('*', 'X'), (('Having', 'NOUN'), ('Having', 'VERB'))],
#  [('a', 'DET'), (('supportive', 'NOUN'), ('supportive', 'ADJ'))],
#  [('breakers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('frozen', 'VERB'), (('noodles', 'X'), ('noodles', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('``', '.'), (('Maybe', 'NOUN'), ('Maybe', 'ADV'))],
#  [('a', 'DET'), (('cosmetic', 'NOUN'), ('cosmetic', 'ADJ'))],
#  [('and', 'CONJ'), (('entertaining', 'NOUN'), ('entertaining', 'ADJ'))],
#  [('that', 'DET'), (('means', 'NOUN'), ('means', 'VERB'))],
#  [('means', 'VERB'),
#   (('confrontational', 'NOUN'), ('confrontational', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [('.', '.'), (('There', 'NOUN'), ('There', 'DET'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('factors', 'NOUN'), (('affecting', 'NOUN'), ('affecting', 'VERB'))],
#  [('in', 'ADP'), (('early', 'ADV'), ('early', 'ADJ'))],
#  [('.', '.'), (('Such', 'NOUN'), ('Such', 'ADJ'))],
#  [('of', 'ADP'), (('seconds', 'DET'), ('seconds', 'NOUN'))],
#  [('.', '.'), (('Even', 'NOUN'), ('Even', 'ADV'))],
#  [('can', 'VERB'), (('catch', 'NOUN'), ('catch', 'VERB'))],
#  [("'s", 'PRT'), (('fancy', 'VERB'), ('fancy', 'NOUN'))],
#  [('a', 'DET'), (('strategic', 'NOUN'), ('strategic', 'ADJ'))],
#  [('*', 'X'), (('servicing', 'NOUN'), ('servicing', 'VERB'))],
#  [('opportunities', 'NOUN'), (('arise', 'NOUN'), ('arise', 'VERB'))],
#  [('a', 'DET'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('or', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('more', 'ADV'), (('cumbersome', 'VERB'), ('cumbersome', 'ADJ'))],
#  [('wild', 'ADJ'), (('stock-price', 'ADJ'), ('stock-price', 'NOUN'))],
#  [('.', '.'), (('Among', 'NOUN'), ('Among', 'ADP'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Such', 'NOUN'), ('Such', 'ADJ'))],
#  [('investment', 'NOUN'), (('focus', 'VERB'), ('focus', 'NOUN'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('.', '.'), (('These', 'NOUN'), ('These', 'DET'))],
#  [('their', 'PRON'), (('monopoly', 'ADV'), ('monopoly', 'NOUN'))],
#  [('So', 'ADV'), (('crunch', 'VERB'), ('crunch', 'NOUN'))],
#  [('from', 'ADP'), (('above', 'ADP'), ('above', 'ADV'))],
#  [('very', 'ADV'), (('obvious', 'VERB'), ('obvious', 'ADJ'))],
#  [('obvious', 'ADJ'), (('exit', 'X'), ('exit', 'NOUN'))],
#  [('at', 'ADP'), (('prayer', 'DET'), ('prayer', 'NOUN'))],
#  [('of', 'ADP'), (('millionaires', 'DET'), ('millionaires', 'NOUN'))],
#  [('their', 'PRON'), (('20s', 'VERB'), ('20s', 'NUM'))],
#  [('and', 'CONJ'), (('30s', 'NOUN'), ('30s', 'NUM'))],
#  [('in', 'ADP'), (('replacement-car', 'ADJ'), ('replacement-car', 'NOUN'))],
#  [('in', 'ADP'), (('accidents', 'DET'), ('accidents', 'NOUN'))],
#  [('100-megabyte', 'ADJ'), (('hard', 'ADV'), ('hard', 'ADJ'))],
#  [('.', '.'), (('Here', 'NOUN'), ('Here', 'ADV'))],
#  [('with', 'ADP'), (('unsecured', 'VERB'), ('unsecured', 'ADJ'))],
#  [('.', '.'), (('However', 'NOUN'), ('However', 'ADV'))],
#  [('the', 'DET'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('stocks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'ll", 'VERB'), (('weather', 'NOUN'), ('weather', 'VERB'))],
#  [("'s", 'PRT'), (('floral', 'VERB'), ('floral', 'ADJ'))],
#  [('earlier', 'ADJ'), (('tender', 'NOUN'), ('tender', 'ADJ'))],
#  [('continuing', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [("''", '.'), (('What', 'NOUN'), ('What', 'PRON'))],
#  [('.', '.'), (('According', 'NOUN'), ('According', 'VERB'))],
#  [("'s", 'PRT'), (('estimates', 'VERB'), ('estimates', 'NOUN'))],
#  [('not', 'ADV'), (('volunteer', 'VERB'), ('volunteer', 'NOUN'))],
#  [('volunteer', 'NOUN'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('--', '.'), (('teetering', 'NOUN'), ('teetering', 'VERB'))],
#  [('on', 'ADP'), (('insolvency', 'DET'), ('insolvency', 'NOUN'))],
#  [('a', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('the', 'DET'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('reported', 'VERB'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('better', 'ADJ'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('the', 'DET'), (('standardized', 'VERB'), ('standardized', 'ADJ'))],
#  [('an', 'DET'), (('avid', 'NOUN'), ('avid', 'ADJ'))],
#  [('People', 'NOUN'), (('close', 'VERB'), ('close', 'ADJ'))],
#  [('to', 'PRT'), (('guarantee', 'NOUN'), ('guarantee', 'VERB'))],
#  [('seven-million-ton', 'ADJ'), (('cut', 'VERB'), ('cut', 'NOUN'))],
#  [('annual', 'ADJ'), (('sulfur-dioxide', 'ADJ'), ('sulfur-dioxide', 'NOUN'))],
#  [('emissions', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('acid', 'ADJ'), ('acid', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('*U*', 'X'), (('tool', 'VERB'), ('tool', 'NOUN'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('the', 'DET'), (('impending', 'VERB'), ('impending', 'ADJ'))],
#  [('impending', 'ADJ'), (('attack', 'VERB'), ('attack', 'NOUN'))],
#  [("n't", 'ADV'), (('enough', 'ADV'), ('enough', 'ADJ'))],
#  [('ring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('That', 'NOUN'), ('That', 'DET'))],
#  [('rumored', 'VERB'), (('target', 'VERB'), ('target', 'NOUN'))],
#  [('was', 'VERB'), (('raring', 'X'), ('raring', 'ADJ'))],
#  [('.', '.'), (('Among', 'NOUN'), ('Among', 'ADP'))],
#  [('for', 'ADP'), (('rear', 'DET'), ('rear', 'ADJ'))],
#  [('was', 'VERB'), (('soliciting', 'X'), ('soliciting', 'VERB'))],
#  [('sell', 'VERB'), (('TXO', 'X'), ('TXO', 'NOUN'))],
#  [('.', '.'), (('When', 'NOUN'), ('When', 'ADV'))],
#  [('*-5', 'X'), (('mindful', 'VERB'), ('mindful', 'ADJ'))],
#  [('The', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('from', 'ADP'), (('malignant', 'DET'), ('malignant', 'ADJ'))],
#  [('0', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('on', 'ADP'), (('profit-taking', 'ADJ'), ('profit-taking', 'NOUN'))],
#  [('most', 'ADV'), (('favored', 'VERB'), ('favored', 'ADJ'))],
#  [('buy', 'VERB'), (('jam', 'X'), ('jam', 'NOUN'))],
#  [('and', 'CONJ'), (('charge', 'NOUN'), ('charge', 'VERB'))],
#  [('.', '.'), (('Neither', 'NOUN'), ('Neither', 'DET'))],
#  [('would', 'VERB'), (('disclose', 'X'), ('disclose', 'VERB'))],
#  [("'s", 'PRT'), (('cost', 'VERB'), ('cost', 'NOUN'))],
#  [('for', 'ADP'), (('alleged', 'VERB'), ('alleged', 'ADJ'))],
#  [('alleged', 'ADJ'), (('improper', 'NOUN'), ('improper', 'ADJ'))],
#  [('improper', 'ADJ'), (('use', 'VERB'), ('use', 'NOUN'))],
#  [('to', 'PRT'), (('crack', 'NOUN'), ('crack', 'VERB'))],
#  [('crack', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('was', 'VERB'), (('down', 'ADV'), ('down', 'ADP'))]]

# %% [markdown]
# ### Following are the cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# Following words were incorrectly tagged as below

# 1. Private - NOUN was tagged as ADJ
# 2. Tokio - NOUN was tagged as DET
# 3. 20.5 - NUM was tagged as NOUN
# 4. touched - VERB was tagged as NOUN
# 5. reasonably - ADV was tagged as NOUN

# all of which got rectified

# %%
# Following is a demonstration of a few test sentences which go through the modified Viterbi as well as application of
# morphological rules

# %%
Test_sentences = []
Test_sentences.append('Android is a mobile operating system developed by Google.')
Test_sentences.append('Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.')
Test_sentences.append("Google and Twitter made a deal in 2015 that gave Google access to Twitter's firehose.")
Test_sentences.append('Twitter is an online news and social networking service on which users post and interact with messages known as tweets.')
Test_sentences.append('Before entering politics, Donald Trump was a domineering businessman and a television personality.')
Test_sentences.append('The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.')
Test_sentences.append('This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.')
Test_sentences.append('Show me the cheapest round trips from Dallas to Atlanta')
Test_sentences.append('I would like to see flights from Denver to Philadelphia.')
Test_sentences.append('Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.')
Test_sentences.append('NASA invited social media users to experience the launch of ICESAT-2 Satellite.')

# %%
for sent in Test_sentences:
    print(apply_morphological_rules(Viterbi_transition(word_tokenize(sent))))
# Out:
# [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.')]
# [('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'DET'), ('since', 'ADP'), ('2011', 'NUM'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'NUM'), ('.', '.')]
# [('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'NUM'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NOUN'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'NOUN'), ("'s", 'PRT'), ('firehose', 'VERB'), ('.', '.')]
# [('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'DET'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'DET'), ('.', '.')]
# [('Before', 'NOUN'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'NOUN'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'NOUN'), ('.', '.')]
# [('The', 'DET'), ('2018', 'NUM'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'ADJ'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'VERB'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.')]
# [('This', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.')]
# [('Show', 'VERB'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN')]
# [('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.')]
# [('Show', 'VERB'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'X'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'NOUN'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.')]
# [('NASA', 'NOUN'), ('invited', 'VERB'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'NOUN'), ('Satellite', 'NOUN'), ('.', '.')]

# %% [raw]
# We notice here that all the key nouns such as Andorid, Twitter, Gooble have got fixed.
# However, we can still see a few inaccuracies such as smartphones which is actually a NOUN but got incorrectly tagged
# as DET. This is due to the fact that it is an UNKNOWN word and the algorithm is merely reliance on its knowledge of
# transition probabilities. A few other inaccuracies are

# %% [markdown]
# ### Final Summary

# %%
# The default algorithm was unable to handle a number of Unknown words, i.e. words that were not in the training set
# This is likely the situation that we will encounter in most scenarios.

# By applying the following 2 techniques:
# 1. Use of transition probabilities where emission probability is missing
# 2. Applying common morphological rules,

# we were able to establish that the prediction accuracy went up
